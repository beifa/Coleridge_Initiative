# %%
import pandas as pd
import numpy as np
from pathlib import Path
from tqdm import tqdm
import matplotlib.pyplot as plt

PATH = '/content/drive/MyDrive/Coleridge_Initiative/input'
PATH_SAVE = '/content/drive/MyDrive/Coleridge_Initiative/input/handles_fix'

df = pd.read_csv(Path(PATH)/ 'bad_data.csv')
df_head = pd.read_csv(Path(PATH) / 'train.csv')

df.drop(['Unnamed: 0'], axis = 1, inplace =True)
df['result_len'] = df.result.apply(lambda x: len(str(x)))

# %%
# bad data make

# def clean_text(txt):
#     return re.sub('[^A-Za-z0-9]+', ' ', str(txt).lower())

# tmp = {}
# for path in tqdm(Path(PATH).glob('train/*.json')):
#     d = pd.read_json(path)
#     for i in d.section_title.values:
#         i = clean_text(i)
#         len_i= list(len(j) for j in i.split())    
#         if all(np.ones_like(len_i) == len_i):
#             tmp[path.stem] = i

# pd.DataFrame(tmp.items(), columns=['Id', 'result']).to_csv('bad_data.csv')

# %% [markdown]
# ## 19

# %%
df[df.result_len == 19]
# Out:
#                                         Id               result  result_len
# 828   ed53d053-e363-45fd-a1ce-aa5b8d623955  d i s c u s s i o n          19
# 1714  a5e4464b-1ad9-4890-a411-8d84de0aadaa  m a n u s c r i p t          19
# 2608  88cdfbf8-d968-4ea7-8d56-bf7f26e96a27  s t a t i s t i c s          19
# 3421  616ecbc1-972e-455e-a562-2d215fd93878  d i s c u s s i o n          19
# 4107  5720e551-6817-4c23-9773-7aac6c997c79  m a n u s c r i p t          19
# 4921  372ce33f-5cbb-4bca-8c90-e800c4f1e7cf  f i e l d n o t e s          19
# 5564  26b6976f-bae1-4841-98bd-d60f10ed221e  d i s c u s s i o n          19

# %%
df1 = pd.read_json(Path(PATH) /'train' /'ed53d053-e363-45fd-a1ce-aa5b8d623955.json')
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  ABSTRACT: This article describes key findings ...
# 1                                                   R  ecent longitudinal research strongly suggests ...
# 2   A P P R O A C H E S T A K E N T O W A R D S M ...  Virtually all math screening measures for the ...
# 3   PR O C E D U R E F O R REVIE W I N G T H E LIT...  We conducted a literature review using the ERI...
# 4   MEASU R E S O F CRIT I C A L ASPE C T S O F NU...  Most research on screening measures in early p...
# 5   It is difficult for children to become automat...  Measures of fact retrieval appear to be promis...
# 6   M U L T I P L E N U M B E R P R O F I C I E N ...  Another promising approach is the use of measu...
# 7   S C R E E N E R S A L I G N E D T O C U R R I ...  A different approach to screening has been dev...
# ...

# %%
rep =  [
       'Abstract',
       'R',
       'APPROACHES TAKEN TOWARDS MEASURING NUMBER PROFICIENCY IN YOUNG STUDENTS',
       'PROCEDURE FOR REVIEWING THE LITERATURE ON EARLY SCREE N I N G I N MATHEMATICS',
       'MEASURE SOFT CRITICAL ASPECTS OF NUMBER PROFICIENCY',
       'It is difficult for children to become automatic with addition and subtraction number combinations when they do not have a good sense of relations between and among numbers and operations.',
       'MULTIPLE NUMBER PROFICIENCY MEASURES',
       'SCREENER ALIGNED TO CURRICULUM AND ARDS',
       'OTHER MEASURES TO CONSIDER INCLUDING IN A MORE COMPREHENSIVE SCREENING BATTERY',
       'WORKING MEMORY',
       'STUDENT ENGAGEMENT AND ATTENTIVENESS',
       'PREDICTIVE VALIDITY AND DIAGNOSTIC CLASSIFICATION ACCURACY',
       'PREDICTIVE VALIDITY',
       'CLASSIFICATION ACCURACY',
       'SENSITIVITY: ENSURING THAT NO ONE "FALL S THR OUGH THE CRACKS"',
       'SPECIFICITY AND THE CONCERN FOR WASTED RESOURCES',
       'CAN WE BALANCE THE SET TWO CONCERNS ? ROC CURVES AS A POTENTIAL TOOL',
       'EXAMPLE OF AN ROC ANALYSIS',
       'CONTEMPORARY RESEARCH USING ROC ANALYSES : THE SEARCH FOR AN IDEAL BALANCE',
       'DISCUSSION',
       'GRAPPLING WITH THE CONCEPT OF RISK STATUS',
       'POTENTIAL LIMITATIONS OF ROC ANALYSES',
       'ADVANCES IN THE USE OF ROC ANALYSES',
       'OUR PERSPECTIVE ON THE FUTURE'
]

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ 'ed53d053-e363-45fd-a1ce-aa5b8d623955.json')

# %%
f = 'a5e4464b-1ad9-4890-a411-8d84de0aadaa.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Please cite this article as: Oltra-Cucarella, ...
# 1                                 M A N U S C R I P T  A C C E P T E D ACCEPTED MANUSCRIPT\nA C C E P...
# 2                                        INTRODUCTION  The annual risk estimates of progression from ...
# 3                                         Sample data  Data from the Alzheimer's Disease Neuroimaging...
# 4                                           Procedure  Data from 394 NC participants free of any type...
# 5                                    FDG-PET measures  For information about neuroimaging data acquis...
# 6                          Analyses with missing data  To check if our results would replicate in a s...
# 7   Comparison of the risk of AD according to clin...  Using the dataset with complete and estimated ...
# ...

# %%
rep = ['Abstract', '', 'INTRODUCTION', 'Sample data',
       'Procedure', 'FDG-PET measures', 'Analyses with missing data',
       'Comparison of the risk of AD according to clinical profile',
       'RESULTS', 'aMCI groups based on practice effects',
       'Risk of progression to AD', 'ACCEPTED ACCEPTED MANUSCRIPT',
       'Analysis of missing FDG-PET values',
       'Comparison of the AD-risk according to clinical profile',
       'MANUSCRIPT ACCEPTED ACCEPTED MANUSCRIPT',
       'DISCUSSION']
txt = ''
df1.section_title = rep
df1.text.values[1] = txt
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '88cdfbf8-d968-4ea7-8d56-bf7f26e96a27.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                        section_title                                               text
# 0                                S T A T I S T I C S  \nBet ween 20 0 0 and 20 09, U. S. ethanol pro...
# 1  Regional Differences May Explain Why Total Soy...  Looking at State-level changes in harvested co...

# %%
rep = ['STATISTICS',
'Regional Differences May Explain Why Total Soybean Acreage Did Not Decrease Between 2006 and 2008']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '616ecbc1-972e-455e-a562-2d215fd93878.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                        section_title                                               text
# 0                           Abstract  There is increasing international evidence tha...
# 1                                     S u s a n H a l l a m a n d K e v i n R o g e ...
# 2              M e t h o d o l o g y  This study draws on existing data from three s...
# 3                    F i n d i n g s  The findings are presented in terms of English...
# 4                      E n g l i s h  Analysis of variance showed that there were st...
# 5              M a t h e m a t i c s  There were statistically significant differenc...
# 6  O v e r a l l a t t a i n m e n t  The trends observed in relation to English and...
# 7                D i s c u s s i o n  The evidence presented in this paper provides ...

# %%
rep =['Abstract', '', 'Methodology', 'Findings', 'English', 'Mathematics', 'Overall Attainment', 'Discussion']
df1.section_title = rep
text_fix = 'Susan Hallamand Kevin Rogers relationship between third-and fourth-grade students academic achievement and their participation in music programmes. This was moderated by the quality of the programme; the higher the quality of the programme, the higher the academic attainment. Research based on standardized verbal and mathematics achievement tests in the USA has shown that children who have participated in music courses while in high school perform better with the number of years engaged in music correlated with test performance (Catterall, 1998) . Those young musicians who participate in state wide ensembles also have higher SAT scores than state averages (DeCarbo, Fiese & Boyle, 1990; Henry & Braucht, 2007) . Schellenberg (2006) also showed that music training was associated positively with children performance in school and that those who took music lessons over relatively long periods of time tended to be particularly successfully even when intelligence was controlled for. However, not all of the research supports these findings. Miksza (2007) , using data from National Education Longitudinal Study of 1988 with a sample of 5335, created a composite item which assessed student participation in music for the entire duration of the study from eighth to 12 th grade and measured academic achievement in mathematics, reading comprehension, science and social studies. There were significant differences for all subtests in the initial testing in favour of those who had participated in band, choir or orchestra, but rates of change in mathematics, science and social studies were no greater for the music participants. Indeed, in reading achievement the music participants increased more slowly than non-participants. In a later study Miszka (2010) using data from the Educational Longitudinal Study of 2002, taking account of a wider range of variables studied the impact of musical engagement on standardized mathematics scores and found that students in high-school music ensembles were more likely to have higher standardised mathematics achievement scores.Also in the USA, Southgate and Roscigno (2009) -using two national data sets, ECLS-K (20,000 US kindergarten students) and NELS:88 (25,000 adolescents), and three measures of music participation (in school, outside school and parental involvement in the form of concert attendance) -found that music involvement varied systematically by class and gender status. Involvement had implications for both mathematics and reading achievement for young children and adolescents and associations between music and achievement persisted even when prior achievement was taken into account. Musical engagement generally increased achievement levels, although gains were not distributed equally among all students; a white student advantage existed.'
df1.text.values[1] = text_fix
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '5720e551-6817-4c23-9773-7aac6c997c79.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Mendelian adult-onset leukodystrophies are a s...
# 1                                                      caused by mutations in NOTCH3, HTRA1, TREX1, A...
# 2                               MATERIALS AND METHODS
# 3           Adult-onset Leukodystrophy gene selection  The selected genes are all Mendelian leukodyst...
# 4                            Gene expression analysis  We have used microarray data publicly availabl...
# 5                                   Genetic screening  The discovery cohort\nThe discovery cohort was...
# 6                               The follow-up dataset  The follow-up dataset was composed of 296 AD a...
# 7                                   Sanger sequencing  Mutations in CSF1R TK domain and flanking regi...
# ...

# %%
rep = ['Abstract', '', 'MATERIALS AND METHODS',
       'Adult-onset Leukodystrophy gene selection',
       'Gene expression analysis', 'Genetic screening',
       'The follow-up dataset', 'Sanger sequencing',
       'Statistical Analysis', 'RESULTS', 'S4).',
       'Embryonal hippocampi and Primary neuronal cortical cultures oxygen glucose deprivation (OGD) experiments',
       'Single-gene based analysis', 'Single-variant based analysis',
       'Singletons in CSF1R TK domain', 'Patient E (p.Q691H)',
       'Patient F (p.H703Y)', 'Tissue expression of CSF1R', 'DISCUSSION',
       'Divergent gene expression between AD and WT mouse strains was only detected in aged',
       '', '2009)', 'Figure S1', 'Figure S2']
df1.section_title = rep
df1.text.values[20] = ''
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '372ce33f-5cbb-4bca-8c90-e800c4f1e7cf.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                        Introduction  In a third grade classroom, a teacher and an R...
# 1     Structural features of classrooms are changing.  High-quality texts that meet grade-level expec...
# 2              A Shared Vision of Reading Proficiency  To craft a shared vision of reading proficienc...
# 3   Proficient reading is all about making meaning...  Building proficient readers is not easy work. ...
# 4                                        All Students
# 5                                               White
# 6                    Black Economically Disadvantaged  Only one-third of Tennessee fourth graders sco...
# 7                   Classroom Instructional Practices  What We Know and Where We Can Grow In the fall...
# 8   Teachers are increasingly focused on building ...  Tennessee are spending more time reading, list...
# ...

# %%
rep = ['Introduction', 'Structural features of classrooms are changing.',
       'A Shared Vision of Reading Proficiency',
       'Proficient reading is all about making meaning from text. To do this, readers must accurately, fluently, and independently read a wide range of appropriately complex texts; strategically employ comprehension strategies to analyze key ideas and information; construct interpretations and arguments through speaking and writing; develop vocabulary; and build knowledge about the world.',
       'All Students', 'White', 'Black Economically Disadvantaged',
       'Classroom Instructional Practices',
       "Teachers are increasingly focused on building students' reading and listening comprehension alongside their foundational skills. Students in",
       'Students have sufficient opportunities', '', '',
       '', 'Key Differences in Instruction',
       'Ms. Novak Ms. Wilson Text Selection', 'Question Sequencing',
       'Culminating Task',
       'Improving Instruction Through Focused Coaching',
       'Summer Reading Grants',
       'Three Districts, Three Approaches | Lauderdale County',
       'Will this be enough?', '', '',
       '', '']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '26b6976f-bae1-4841-98bd-d60f10ed221e.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                                      grounded in a common set of challenging standa...
# 1             N C T M A N D R E F O R M E F F O R T S  The NCTM is one of the national organizations ...
# 2    CHARACTERISTICS O F STUDENTS W I T H LD A N D ED  Students with LD and ED exhibit several common...
# 3   TEACHER BELIEFS O F NCTM STANDARDS WITH STUDEN...  In addition to academic and behavioral charact...
# 4                                       P U R P O S E  To date, no studies investigate secondary teac...
# 5                                              SAMPLE  Survey Sampling Procedures. The state of Maryl...
# 6                           Data Analysis Procedures.  Data analysis for the survey included descript...
# 7                                        R E S U LT S
# ...

# %%
rep = ['', 'NCTM AND REFORM EFFORTS',
       'CHARACTERISTICS OF STUDENTS WITH LD AND ED',
       'TEACHER BELIEFS OF NCTM STANDARDS WITH STUDENTS WITH LD AND ED',
       'PURPOSE', '', 'Data Analysis Procedures.',
       '', 'DEMOGRAPHICS',
       'TEACHER FAMILIARITY, CONFIDENCE, AND STUDENT RESPONSE',
       'Special Education Teachers General Education Teachers',
       'BARRIERS', '',
       'Mean Rating of Methods Courses on a 5-Point Scale a Significance',
       'FACTORS AFFECTING TEACHER RESPONSE',
       'Mean Rating on 5-Point Scale a Significance', '',
       'DISCUSSION', '',
       'Non-Hierarchical Regression Analysis for Teacher Perception of Familiarity',
       'LIMITATIONS AND FUTURE RESEARCH',
       'TRAINING AND DISSEMINATION']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 20

# %%
df[df.result_len == 20]
# Out:
#                                         Id                result  result_len
# 1795  b22cf48c-8edb-4e40-8aa6-3356aa092481  u n a l a s k a i s           20
# 2555  7f0bf8bf-80fc-4c2b-8921-d1620e7b4afe  s y e y e y t y t y           20

# %%
f = 'b22cf48c-8edb-4e40-8aa6-3356aa092481.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                                      stranded drift logs. Models that place slip >2...
# 1                                        Introduction  The instrumental catalogue of global seismicit...
# 2                            Tsunami modeling methods  To model Aleutian megathrust ruptures we discr...
# 3   Tsunami runup in 1957 registered by tide gauge...  Historical accounts of tsunami runup in 1957 i...
# 4   Slip models for the Unalaska seismic gap and c...  To reassess the slip distribution in the easte...
# 5   Comparison of modeled and observed tsunami rec...  We compared modeled and observed (de-tided) wa...
# 6   Comparison of modeling results and tsunami run...  We also compared the results of the tsunami si...
# 7                          Discussion and Conclusions  A suite of forward models shows that tsunami w...
# ...

# %%
rep = ['', 'Introduction', 'Tsunami modeling methods',
       'Tsunami runup in 1957 registered by tide gauge, historical accounts and coastal geology',
       'Slip models for the Unalaska seismic gap and comparison with observations',
       'Comparison of modeled and observed tsunami records in Dutch Harbor',
       'Comparison of modeling results and tsunami runup in Stardust Bay',
       'Discussion and Conclusions', '', '',
       '', '']
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '7f0bf8bf-80fc-4c2b-8921-d1620e7b4afe.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Die Dokumente auf EconStor dürfen zu eigenen w...
# 1                                        Introduction  In the literature on the economics of educatio...
# 2                                           The model  (ii) for consumption reasons. Regarding the la...
# 3                           Private vs social optimum  In this section we develop the baseline result...
# 4          s( ,Y ),e ( ,Y ),e ( ,Y ),T ( ,Y ),T( ,Y )  , \nThe first two constraints in (10) are the ...
# 5                                                  11  No externality arises in private choice of edu...
# 6                             Government intervention
# 7                  The design of optimal tuition fees  In this section, the planner sets and collects...
# ...

# %%
rep = ['Abstract', 'Introduction', 'The model',
       'Private vs social optimum',
       '', '',
       'Government intervention', 'The design of optimal tuition fees',
       'Regulated levels of education', 'Discussion',
       'If pre-college tests exist that allow students to perform only up to their ability (or to underperform), then the regulated tuition scheme induces accurate ability signaling while the minimum educational investment scheme does not.',
       'It is notable that the incentive to perform as well as one can on an entry test under the tuition subsidy scheme applies as well if',
       'Summary and concluding remarks', 'Appendix',
       '']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 21

# %%
df[df.result_len == 21]
# Out:
#                                         Id                 result  result_len
# 1926  a999e044-08fd-4cb2-8cff-df154825dfb4  b i o s k e t c h e s          21
# 2923  947d7ad1-fa54-476c-81bd-6bda8c5f6892  c o n c l u s i o n s          21
# 4635  513968fa-e27a-4a19-8a33-da2788c1bd07  c o n c l u s i o n s          21
# 5008  35485436-0818-403c-b321-175e3e48b100  c h a p t e r f i v e          21

# %%
f = 'a999e044-08fd-4cb2-8cff-df154825dfb4.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Aim Our understanding of and ability to predic...
# 1                                        INTRODUCTION  The changing focus of conservation efforts fro...
# 2                                             METHODS
# 3   Data sets and defining decline: analysing exti...  We used the breeding birds of the dry mixed gr...
# 4               Predictor variables for both analyses  We selected variables that were the best studi...
# 5                Data sources for predictor variables  Average body size was determined from local da...
# 6                          Modelling species declines  We used a stepwise regression in a general lin...
# 7                                             RESULTS  The Alberta government-defined decline data se...
# ...

# %%
rep = ['Abstract', 'INTRODUCTION', '',
       'Data sets and defining decline: analysing extinction risk',
       'Predictor variables for both analyses',
       'Data sources for predictor variables',
       'Modelling species declines', 'RESULTS', 'DISCUSSION',
       'Government-defined decline versus BBS-defined decline in Alberta, Canada',
       'Comparing degree of decline between Alberta and Saskatchewan',
       'CONCLUSION', '', '', 'BIOSKETCHES',
       '']
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '947d7ad1-fa54-476c-81bd-6bda8c5f6892.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  A multiregion computable general equilibrium m...
# 1                                                      agreement with the European Union, along with ...
# 2                                                   2  A second approach is to take price changes fro...
# 3              I. A MULTIREGIONAL T R A D E M O D E L  A comparative static, constant returns to scal...
# 4                                                   7
# 5                                Brazilian Households  The most important new feature in this model i...
# 6                       General Data and Elasticities  The Global Trade Assistance and Protection 5 (...
# 7                                     Protection Data  All distortions are represented as ad valorem ...
# ...

# %%
rep =['Abstract', '', '', 'I. A MULTIREGIONAL TRADE MODEL', '',
       'Brazilian Households', 'General Data and Elasticities',
       'Protection Data', 'Brazilian Data for Poverty Analysis', '',
       '', '', 'RESULTS AT THE', '',
       'Regional Arrangements', '', '', '', '', '',
       'Tariff Cuts and Uniformity in Mercosur or Multilateral Liberalization-or Both',
       '', 'CONCLUSIONS']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '513968fa-e27a-4a19-8a33-da2788c1bd07.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                        section_title                                               text
# 0                                           Abstract  The geographical distribution of a species is ...
# 1                            I N T R O D U C T I O N  The problem of understanding the nature of the...
# 2  G E O G R A P H I C A L V A R I A T I O N I N ...  It has been known for a long time that species...
# 3  COMPLEMENTARY MODELS O F THE G EO G R APH I C ...  The macroscopic scale\nIn a macroscopic sense,...
# 4                              The microscopic scale  A mechanistic understanding of the geographica...
# 5  The relationship between macro and micro scale...  The major point we wish to emphasize is that a...
# 6  E M P I R I C A L A S S E S S M E N T O F T H ...  The critical parameter in the analysis describ...
# 7  M E C H A N I S M S D E T E R M I N I N G T H ...  The model outlined above provides a theoretica...
# ...

# %%
rep =['Abstract', 'INTRODUCTION',
       'GEOGRAPHICAL VARIATION  IN  ABUNDANCE',
       'COMPLEMENTARY MODELS OF THE GEOGRAPHICAL RANGE',
       'The microscopic scale',
       'The relationship between macro and micro scale descriptions',
       'EMPIRICAL ASSESSMENT OF THE MODEL',
       'MECHANISMS DETERMINING THE RANGE BOUNDARY',
       'DISCUSSION', 'CONCLUSIONS']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 23

# %%
df[df.result_len == 23]
# Out:
#                                         Id                   result  result_len
# 5403  1c83573d-d106-4490-b76c-c072f83cf190  v i c o n c l u s i o n          23

# %%
f = '1c83573d-d106-4490-b76c-c072f83cf190.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                        section_title                                               text
# 0                                           Abstract  Abstract-In this paper, we propose a novel way...
# 1                                                     Abstract-In this paper, we propose a novel way...
# 2                        I . I n t r o d u c t i o n  White matter hyperintensities (WMH) are region...
# 3           A. Data Preparation: Masks o f Brain MRI  The original brain MRI includes non-brain tiss...
# 4  B. Patch Generation: Source Patch and Target P...  Like in previous work [8] , the original MR im...
# 5        C. Age Value Calculation: Distance Function  The core computation of the age map generation...
# 6  D. Final Age Map: Penalty and Global Normalisa...  The age map generated enhanced voxels that are...
# 7  I V . E x p e r i m e n t a n d V i s u a l R ...  We used T2-Fluid Attenuation Inversion Recover...
# ...

# %%
rep = ['Abstract', '', 'Introduction',
       'Data Preparation: Masks o f Brain MRI',
       'Patch Generation: Source Patch and Target Patch',
       'Age Value Calculation: Distance Function',
       'Final Age Map: Penalty and Global Normalisation',
       'Experiment and Visual Results',
       'Conclusion']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 24

# %%
df[df.result_len == 24]
# Out:
#                                        Id                    result  result_len
# 735  e809f322-7a61-412e-b301-3b242c848879  b o e h l e r t e t a l           24

# %%
f = 'e809f322-7a61-412e-b301-3b242c848879.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Data-recording tags applied to marine animals ...
# 1                                        Introduction  The ability to conduct research on the behavio...
# 2                           B O E H L E R T E T A L .  FIG. 1. Adult female elephant seal with ARGOS ...
# 3                                             Methods
# 4                                          a. Tagging  All elephant seal tagging occurred at the Año ...
# 5                b. Instrumentation and data handling
# 6                               1) ARGOS TRANSMITTERS  Half-watt satellite platform transmitter termi...
# 7                                             Results  The database of northern elephant seal tracks ...
# 8             a. Calibration of temperature and depth  A comparison of temperatures recorded from a C...
# ...

# %%
rep =['Abstract', 'Introduction', 'BOEHLERT ET AL.', 'Methods',
       'Tagging', 'Instrumentation and data handling',
       'ARGOS TRANSMITTERS', 'Results',
       'Calibration of temperature and depth', 'Location accuracy',
       'Comparisons with existing temperature data for the North Pacific',
       'Seal data in the WOD', 'Summary and conclusions',
       'JOURNAL OF ATMOSPHERIC AND OCEANIC TECHNOLOGY']
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 25

# %%
df[df.result_len == 25]
# Out:
#                                         Id  ... result_len
# 1009  cc79b06f-5c77-45e7-ab98-7d2191136246  ...         25
# 1604  c91d12e0-1a02-4a36-8bea-351b711dd62e  ...         25
# 3284  7ed9cbbe-ceb1-47a0-886e-2867ea5406cc  ...         25
# 3640  6702fcbc-eea5-4407-a4df-35c9331087c7  ...         25
# 4532  4651dc5f-08c8-4deb-adc9-c394d1c23935  ...         25
# 6145  0322119f-2de1-4675-96ce-75fba821c992  ...         25
#
# [6 rows x 3 columns]

# %%
f = 'cc79b06f-5c77-45e7-ab98-7d2191136246.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                          section_title                                               text
# 0                             Abstract  This report provides a detailed set of histori...
# 1                       | INTRODUCTION  Targeting of remedial efforts in lakes require...
# 2           | Mining (USGS, 1844-2012)  Given its importance to the economies of Great...
# 3  | Agriculture (Canada Census Office  2.4 | Forests (Supplement S1, Reavie et al., 2...
# 4                      ACKNOWLEDGMENTS  The compilation of historical records was supp...
# 5            O P E N P R A C T I C E S  This article has earned an Open Data badge for...

# %%
rep =['Abstract', 'INTRODUCTION', 'Mining (USGS, 1844-2012)',
       'Agriculture (Canada Census Office', 'ACKNOWLEDGMENTS',
       'OPEN PRACTICES']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = 'c91d12e0-1a02-4a36-8bea-351b711dd62e.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                       section_title                                               text
# 0                                          Abstract  A recent class of factor demand models is disc...
# 1                                                 3
# 2                                    The Cost Model  The approach taken here stems from the concept...
# 3                                          W Z   where  is the inverse of C  with respect to ...
# 4                                                 8  This model is nonlinear in variable cost, crea...
# 5                                        Estimation  The estimation method is a parametric form of ...
# 6                                                 9  (1) Estimate the structural parameters through...
# 7                                              Data  The main data set analyzed in the empirical ap...
# 8                                                11  Although contemporaneous, the variables in the...
# ...

# %%
rep = ['Abstract', '', 'The Cost Model',
       '', '', 'Estimation', '', 'Data',
       '', 'Results', 'Structural Breaks',
       'Intertemporal and Spatial Correlation Estimates',
       'Functional Form', '',
       'Economic Regularity and Elasticity Estimates',
       'Further Robustness of Model Estimates', '',
       'Conclusions', '']


df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '7ed9cbbe-ceb1-47a0-886e-2867ea5406cc.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                                      tion), and emotional disabilities (ED), in par...
# 1                                 B A C K G R O U N D
# 2   BRI E F HIS T O R I C A L A N D LEGI S L AT I ...  Disproportionality was formally acknowledged i...
# 3   PAT T E R N S O F DIS P R O P O R T I O N A L ...  Findings of racial disproportionality have bee...
# 4   FACTO R S REL AT E D T O DISP R O P O R T I O ...  Scholars have acknowledged that disproportiona...
# 5   LIMITATIONS T O T H E EXIS T I N G DISPR O P O...  The study of disproportionality has long been ...
# 6                                  PRES E N T STU D Y  The purpose of this study was to examine patte...
# 7                                         M E T H O D
# 8                                             SAMPL E  We took the sample from archival data from one...
# ...

# %%
rep = ['', '',
       'BRIEF HISTORICAL AND LEGISLATIVE CONTEXT',
       'PATTERNS OF DISPROPORTIONALITY IN SPECIAL EDUCATION',
       'FACTORS RELATED TO DISPROPORTIONATE REPRESENTATION',
       'LIMITATIONS TO THE EXISTING DISPROPORTIONALITY RESEARCH',
       'PRESENT STUDY', '', '', 'ANALYSES',
       'RESULTS DESCRIPTIVE ANALYSES O F RIS K',
       'MULTILEVEL PREDICTORS OF SPECIAL EDUCATION IDENTIFICATION',
       'Students with higher attendance rates were significantly less likely to have been identified for special education.',
       'DISCUSSION',
       'PATTERN OF DIFFERENTIAL RISK', '',
       '',
       '',
       '',
       'Individual-and Two-level Logistic Regression Models: Odds Ratios',
       'MULTILEVEL ANALYSIS OF RISK', 'LIMITATIONS',
       'IMPLICATIONS FOR RESEARCH',
       'PRACTICAL IMPLICATIONS', 'FINAL THOUGHTS']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '6702fcbc-eea5-4407-a4df-35c9331087c7.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                          section_title                                               text
# 0                                       threats that humanity faces in the future, he ...
# 1                      COMBING RECORDS  On 6 February 1978, a blizzard of historic pow...
# 2                         BACK IN TIME  The researchers also discovered extreme events...
# 3  N O R T H A M E R I C A E U R O P E                                     Atlantic Ocean
# 4            S O U T H E A S T A S I A                                     Philippine Sea
# 5                         Paci c Ocean
# 6                    THE COMING FLOODS  Mean sea levels are rising around the globe, w...

# %%
rep = ['', 
       'COMBING RECORDS',
       'BACK IN TIME',
       'NORTH HAMER ICA EUROPE',
       'SOUTHEAST ASIA',
       'Paci c Ocean', 
       'THE COMING FLOODS']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '0322119f-2de1-4675-96ce-75fba821c992.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                          section_title                                               text
# 0                             Abstract  knew what was heading for his hometown: catego...
# 1                                       threats that humanity faces in the future, he ...
# 2                      COMBING RECORDS  On 6 February 1978, a blizzard of historic pow...
# 3                         BACK IN TIME  The researchers also discovered extreme events...
# 4  N O R T H A M E R I C A E U R O P E                                     Atlantic Ocean
# 5            S O U T H E A S T A S I A                                     Philippine Sea
# 6                         Paci c Ocean
# 7                    THE COMING FLOODS  Mean sea levels are rising around the globe, w...

# %%
rep = ['Abstract',
       '',
       'COMBINE RECORDS',
       'BACK IN TIME', 
       '',
       '',
       '',
       'THE COMING FLOODS']
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 26

# %%
df[df.result_len == 26]
# Out:
#                                         Id  ... result_len
# 2234  979fcaf1-cf50-4507-808e-6dc69c04e16a  ...         26
# 2254  9722060f-2033-47dd-ad1d-8f2e1bf88065  ...         26
# 3967  57dcb4a8-9194-4167-8f73-5a626cdbcad5  ...         26
#
# [3 rows x 3 columns]

# %%
f = '979fcaf1-cf50-4507-808e-6dc69c04e16a.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                                      1. INTRODUCTION .................................
# 1                 ABSTRACT-J. BLUNDEN AND D. S. ARNDT  In 2018, the dominant greenhouse gases release...
# 2                                      b. Temperature  1) Global surface temperature-A. Sánchez-Lugo,...
# 3                                              Global
# 4                                           NASA-GISS  In 2018, the satellite-derived LSWT anomaly av...
# ..                                                ...                                                ...
# 70                                  7) eaStern eUrope  This region includes the European part of Russ...
# 71                                     8) Middle eaSt  This region includes Israel, Cyprus, Jordan, L...
# ...

# %%
rep = ['', 'ABSTRACT-J. BLUNDEN AND D. S. ARNDT', 'Temperature',
       'Global', 'NASA-GISS', 'Index Definition', '', '', '',
       '', '', '', '', '',
       'alpine Glaciers-M. Pelto and World Glacier Monitoring',
       'Hydrological cycle', 'upper tropospheric humidity-',
       'land surface precipitation extremes',
       'river discharGe and runoff-H. Kim',
       'Groundwater and terrestrial water storaGe-',
       'carbon monoxide-J. Flemming and A. Inness',
       'GLOBAL OCEANS a. Overview-R. Lumpkin', 'Product',
       'Surface heat fluxeS', 'Surface freShwater fluxeS',
       'long-term perSpectIve', 'pacIfIc ocean',
       'aIr-Sea carbon dIoxIde fluxeS',
       'global ocean carbon InventorIeS', 'ENSO and the tropical',
       'Oceanic cOnditiOns',
       'Global monsoon summary-B. Wang and Q. He', 'Region',
       'Storm formation regions, tracks, and landfalls',
       'Sea surface temperatures', 'Atmospheric conditions',
       'Environmental influences on the 2018 season',
       'Tropical cyclone impacts',
       'western nOrth pacific basin-S. J. Camargo (i) Introduction',
       'Environmental conditions',
       'Landfalling and other significant tropical cyclones',
       'Landfalling and other significant cyclones',
       'UPPER-OCEAN CONDITIONS IN THE GULF OF MEXICO DURING HURRICANE MICHAEL-G. J. GONI AND R. DOMINGUES',
       'Mean annual land surface air teMperature',
       'Geopotential heiGhts and resultinG reGional teMperature patterns',
       'Sea surface temperature-M.-L. Timmermans and C. Ladd',
       'Sea ice', 'van de Wal', 'ice Mass Balance', 'alBedo',
       'Marine-terMinatinG Glaciers', '1) perMafrost teMperatures',
       'active layer thickness',
       'Seasonal melt extent and duration-L. Wang and H. Liu',
       'Surface mixed layer propertieS', 'de Laat', 'North',
       'Temperature', 'Precipitation',
       'Notable events and impacts', 'MexiCo-R. Pascual Ramírez',
       'South America', 'SoUthern afriCa-G. Mengistu',
       'Europe and the Middle', 'overvieW',
       'Analysis: Blocking high-pressure system',
       'Analysis: Moisture sources', 'Economic impacts',
       'iberian peninSUla', '6) Mediterranean and balkan StateS',
       'eaStern eUrope', 'Middle eaSt', 'SoUth CaUCaSUS',
       'EXTENDED DROUGHT IN AUSTRALIA IN 2018-S. TOBIN AND L. BETTIO',
       '']

df1.section_title = rep
df1.text.values[0] = ''
df1.text.values[6] = ''
df1.text.values[7] = ''
df1.text.values[8] = ''
df1.text.values[9] = ''
df1.text.values[10] = ''
df1.text.values[11] = ''
df1.text.values[12] = ''
df1.text.values[13] = ''
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '9722060f-2033-47dd-ad1d-8f2e1bf88065.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                                      Migration across national borders provokes man...
# 1              NEGATIVE EFFECTS FOR SENDING COUNTRIES  A loss of productive capacity due to the at le...
# 2              POSITIVE EFFECTS FOR SENDING COUNTRIES  Less often discussed are positive effects that...
# 3             Incentives for human capital investment  The most difficult to measure, but theoretical...
# 4               E(H)= P m E f (H) + (1 -P m ) E d (H)  where P m is the subjective individual probabi...
# 5                  Knowledge flows and collaborations  International migrants (other than refugee) se...
# 6   Return of natives with foreign education and h...  An important, but not necessary, way for a sen...
# 7                      Support from diaspora networks  There are in the general immigration literatur...
# ...

# %%
rep = ['', 'NEGATIVE EFFECTS FOR SENDING COUNTRIES',
       'POSITIVE EFFECTS FOR SENDING COUNTRIES',
       'Incentives for human capital investment',
       '',
       'Knowledge flows and collaborations',
       'Return of natives with foreign education and human capital',
       'Support from diaspora networks',
       'NEGATIVE EFFECTS FOR RECEIVING COUNTRIES',
       'Decreased incentive for natives to seek higher skills',
       'Crowding out of natives from advanced education',
       'Other negative effects',
       'POSITIVE EFFECTS FOR RECEIVING COUNTRIES',
       'Increased Economic Activity and R&D',
       'Knowledge flows and collaboration',
       'Increased enrollment in graduate programs', 'GLOBAL EFFECTS']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '57dcb4a8-9194-4167-8f73-5a626cdbcad5.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                      section_title                                               text
# 0                     Introduction  COVID-19, a respiratory disease caused by a ne...
# 1        The proposed model system  The mathematical framework of an age-structure...
# 2              Simulation analysis  The infection curves predicted by our model ar...
# 3  New strategies and their impact  The effectiveness of control strategies can be...
# 4      Discussions and conclusions  Our model of COVID-19 dynamics allows us to ma...
# 5             A Calculation of R 0  Here, we find the basic reproduction number us...
# 6    T = T I I T I Q T Q I T Q Q ,  The basic reproductive number R 0 = ρ(T V −1 )...
# 7             B List of parameters  Here, we list the parameters used in our numer...

# %%
rep =['Introduction', 'The proposed model system', 'Simulation analysis',
       'New strategies and their impact', 'Discussions and conclusions',
       'Calculation of R0', '',
       'List of parameters']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 27

# %%
df[df.result_len == 27]
# Out:
#                                         Id  ... result_len
# 1688  d2a5e991-7788-43a9-bd5d-6b58a105ad05  ...         27
# 3481  6633c510-851d-45ec-a2b5-35929933fd93  ...         27
# 5497  27f4b2ca-64c6-4dfa-8a56-6e01d253a687  ...         27
# 5774  0c8839af-3458-4180-a4c8-1350bcce9da1  ...         27
#
# [4 rows x 3 columns]

# %%
f = '6633c510-851d-45ec-a2b5-35929933fd93.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Abstract. The aim of this study was to evaluat...
# 1                                        INTRODUCTION  Revised criteria for the diagnosis of Alzheime...
# 2                                             METHODS  Data used in this study were obtained from the...
# 3                                            Subjects  The study included all ADNI subjects with 1) b...
# 4                             Neuropsychological data  The modified Alzheimer's Disease Assessment Sc...
# 5                                 Structural MRI data  All images were downloaded as "unpreprocessed"...
# 6                            Cerebrospinal fluid data  Baseline CSF data was obtained from the master...
# 7                                        FDG PET data  In 400 of the 416 subjects, FDG PET had been a...
# ...

# %%
rep = ['Abstract', 'INTRODUCTION', 'METHODS', 'Subjects',
       'Neuropsychological data', 'Structural MRI data',
       'Cerebrospinal fluid data', 'FDG PET data', 'Survival analysis',
       'RESULTS',
       '',
       'DISCUSSION', 'Corrected Proof', 'Conclusion']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 29

# %%
df[df.result_len == 29]
# Out:
#                                         Id  ... result_len
# 27    ef228135-27af-4278-a225-57acd2ac0a82  ...         29
# 157   f1b680dc-b2d1-41ee-a081-1c980933c24e  ...         29
# 431   e1d48626-1fc1-4682-a2ac-a1c985e2d08b  ...         29
# 491   dd00f940-bdc9-4b05-9c96-fbdc69a8b888  ...         29
# 716   ec71b9e6-d84e-4ac3-ba7a-104d46481614  ...         29
# 763   ec6b359f-8d69-4a5f-b65b-e3b6c40a0320  ...         29
# 786   e9721734-5da1-4104-b1db-f00a6f92ff9e  ...         29
# 944   ca2efc83-2e7a-4f7b-b9f9-5c1aa333ae86  ...         29
# 956   cb3e8a60-1d46-4583-822b-877dfd452cdb  ...         29
# 1040  d0844d89-7700-4461-884a-cf5a486471de  ...         29
# 1104  d5d6b9c3-9c77-469e-9ba2-d4192ad5ecdd  ...         29
# 1183  d595ffae-fac7-430d-a9f0-8dd12aaad980  ...         29
# 1317  b3e186c0-bb69-4968-a315-36f3e7e49b79  ...         29
# 1387  bf84fe87-0d9b-48ab-a24e-ccccfb60af2a  ...         29
# 1525  c789df9a-d87b-457b-a837-1f4018cd4293  ...         29
# ...

# %%
f = '8f93d695-421d-425c-a6ad-4bf0fc895dfa.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Alzheimer's disease (AD) was first described a...
# 1                                            OVERVIEW  Alois Alzheimer, a German psychiatrist, report...
# 2                             CLINICAL FEATURES OF AD  Dementia is an acquired syndrome characterized...
# 3                      THE PATHOLOGICAL PROCESS IN AD  The key neuropathological elements of AD were ...
# 4             AD GENETICS AND LINK TO PATHOPHYSIOLOGY  Despite the discovery by Alois Alzheimer in 19...
# 5                 S T A T E O F T H E A R T R E V I E  \nApproaches for identifying new risk factors ...
# 6       THE CONNECTION AMONG APP, Ab, AND PRESENILINS  In addition to APP, mutations in two other gen...
# 7           APOLIPOPROTEIN E, THE ENVIRONMENT, AND AD  In addition to the genetics of FAD in which mu...
# ...

# %%
rep = ['Abstract', 'OVERVIEW', 'CLINICAL FEATURES OF AD',
       'THE PATHOLOGICAL PROCESS IN AD',
       'AD GENETICS AND LINK TO PATHOPHYSIOLOGY',
       'STATE OF THE ART REVIEW',
       'THE CONNECTION AMONG APP, Ab, AND PRESENILINS',
       'APOLIPOPROTEIN E, THE ENVIRONMENT, AND AD',
       'STATE OF THE ART REVIEW', 'CONNECTING Ab AND TAU',
       'PREVENTION OF Ab AND TAU AGGREGATION',
       'THE CONUNDRUM AMONG BIOMARKERS, PATHOLOGY, AND TREATMENT',
       '', 'SUMMARY']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
regular = r"\bJ o u r n a l P r e -p r o o f\b"
for file_name in tqdm(df[df.result_len == 29]['Id'].values):    
    if file_name != '8f93d695-421d-425c-a6ad-4bf0fc895dfa':
        tmp = pd.read_json(Path(PATH)/ 'train' /f'{file_name}.json')
        tmp.section_title.replace(regular,'Journal Pre-proof',regex=True, inplace=True)
        tmp.text.replace(regular,'Journal Pre-proof',regex=True, inplace=True)
        tmp.to_json(Path(PATH_SAVE)/ f'{file_name}.json')
# Out:
# 100%|██████████| 49/49 [00:44<00:00,  1.10it/s]

# %% [markdown]
# ## 30

# %%
df[df.result_len == 30]
# Out:
#                                         Id  ... result_len
# 3097  79a7be3a-5e8d-4359-8c5d-04323f5fc3ac  ...         30
# 4197  618957b2-331f-43f9-bdcb-34a3a96534be  ...         30
#
# [2 rows x 3 columns]

# %%
f = '79a7be3a-5e8d-4359-8c5d-04323f5fc3ac.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0          Meet Marcel Agüeros at Columbia University
# 1                     I N S I D E T H I S I S S U E :  A report on underrepresented minorities in ast...
# 2                                H I G H L I G HT S :  • Read a new AAAS report highlighting statisti...
# 3                                 JANUARY 2007 PAGE 2  Low though they are, the percentages of physic...
# 4                       Diversity in Physics (cont'd)  ics PhDs awarded to URMs in 2004 were 4.8% of ...
# 5                  Institutions That Serve Minorities  Historically black colleges and universities a...
# 6                    New pathways to doctoral degrees  • Two-year colleges vastly increased their rol...
# 7                             Increasing Indebtedness  • In 1999, for the first time, more than half ...
# ...

# %%
rep = ['',
       'INSIDE THE ISSUE :', 'HIGHLIGHTS :',
       '', "Diversity in Physics (cont'd)",
       'Institutions That Serve Minorities',
       'New path ways to doctoral degrees', 'Increasing Indebtedness',
       'Field Choices and Demographic Characteristics of Doctoral Recipients',
       'Sex. Men received about 73 percent of all doctor',
       'Changes in demographics',
       'NSF Report Reveals Century of Doctoral Education Trends in the United States',
       '', '', 'Curriculum and Community',
       'Involving Faculty, Staff, and Students',
       '',
       'Baccalaureate Institutions', 'A human activity',
       'Fixing the System',
       'Meet Marcel Agüeros, NSF Postdoctoral Fellow at Columbia University by Keivan G. Stassun',
       "Preparing Minority Scientists and Engineers (cont'd)",
       'After the Degree',
       '']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '618957b2-331f-43f9-bdcb-34a3a96534be.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  We conducted a meta-analysis on 64 econometric...
# 1                                        Introduction  Forestland change is ubiquitous across America...
# 2                         Vote Counting Meta-Analysis  The objective of this study was to the review ...
# 3   Determining Vote Count "Success" for Independe...  There are numerous ways meta-analysis vote cou...
# 4                                             Methods
# 5                          Rules for Model Acceptance  Over 200 articles were reviewed on LULC change...
# 6                                                 F2A  Forestland Agriculture Typically specifies for...
# 7                                                 U2D  Undeveloped Developed/Urban Groups forestland,...
# ...

# %%
rep = ['Abstract', 'Introduction', 'Vote Counting Meta-Analysis',
       'Determining Vote Count "Success" for Independent Variables Used in Econometric LULC Change Studies',
       '', 'Rules for Model Acceptance', '', '', '',
       'Independent Variable Classification and Analytical Framework',
       '', 'Accepted Models Description', '',
       'Frequency of Model Use by Econometric Drivers and Categories',
       'Government Policy', 'Forestry Incentive Programs',
       'Zoning Effects on Forestland Loss', 'Site Characteristics',
       'Development', 'Socioeconomic', 'Vote Count Analysis Results',
       '', 'All Market Drivers',
       'Government Policy',
       '', 'Discussion', 'Market Drivers',
       'Socioeconomic Characteristics',
       'Recommendation of Independent Variables by Model Type',
       'Forest to Agriculture Models', 'Forest to Development Models',
       'Undeveloped to Developed Models', 'Forest to Non-Forest Models',
       'Important Considerations', 'Author Contributions',
       'Conflicts of Interest']
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 31

# %%
df[df.result_len == 31]
# Out:
#                                         Id  ... result_len
# 1200  d839a265-f638-4c38-8ed1-f84bad1a93da  ...         31
# 4002  595023e7-8a3d-4195-b823-8d76151408ec  ...         31
# 4360  3fb05deb-1be3-4bb0-8895-fed15ad64bb5  ...         31
# 4675  50855997-3d34-4468-8034-a3b4f4a687ac  ...         31
# 5824  0f27120c-a6d2-4657-8cf0-2cb1709dab02  ...         31
#
# [5 rows x 3 columns]

# %%
f = 'd839a265-f638-4c38-8ed1-f84bad1a93da.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Aim: Combined PET/MR systems have now become a...
# 1                     t r a c t a r t i c l e i n f o  Introduction Dual-modality imaging by means of...
# 2                               Materials and methods  Patient studies were performed using a fully-i...
# 3                                       Phantom study  A 2 L plastic bottle was fitted with a layer o...
# 4                             Patient characteristics  19 patients (9 male, 10 female, mean age (68 ±...
# 5                                  PET/CT acquisition  Patients were positioned head-first supine on ...
# 6                         PET/CT image reconstruction  PET images from the PET/CT were reconstructed ...
# 7                                  PET/MR acquisition  Patients were positioned in the PET/MR in supi...
# ...

# %%
rep = ['Abstract', 'tract article info',
       'Materials and methods', 'Phantom study',
       'Patient characteristics', 'PET/CT acquisition',
       'PET/CT image reconstruction', 'PET/MR acquisition',
       'Bone tissue extraction and PET/MR image reconstruction',
       'PET image analysis', '', 'Clinical PET/MR study',
       'Discussion', 'Limitations', 'Conclusion']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '595023e7-8a3d-4195-b823-8d76151408ec.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Biological control is an underlying pillar of ...
# 1                                        INTRODUCTION  The grand challenge to meet the increasing dem...
# 2                   METHODS AND ANALYTICAL APPROACHES  Methods of estimating economic values of BC va...
# 3                               BENEFIT-COST ANALYSIS  Benefit-cost analysis is a formal approach to ...
# 4                               Benefit-Cost Analysis  Benefit-cost analysis is an analytical framewo...
# 5                                Contingent Valuation  The contingent valuation method (CVM) is a dir...
# 6                        CLASSICAL BIOLOGICAL CONTROL  Classical BC was formally initiated in the lat...
# 7                     CONSERVATION BIOLOGICAL CONTROL  Conservation BC involves changes to the crop e...
# ...

# %%
rep = ['Abstract', 'INTRODUCTION', 'METHODS AND ANALYTICAL APPROACHES',
       'BENEFIT-COST ANALYSIS', 'Benefit-Cost Analysis',
       'Contingent Valuation', 'CLASSICAL BIOLOGICAL CONTROL',
       'CONSERVATION BIOLOGICAL CONTROL',
       'Economics of Biological Control',
       'Broad Estimates of Ecosystem Services',
       'Insecticides and Natural Enemy Conservation',
       'Economic Thresholds and Biological Control',
       'Experimental Manipulations and Models',
       'Habitat Modification Landscape Management', 'Synthesis',
       'A CALL TO ARMS',
       'Economics of Biological Control 32.13',
       'Uncorrected Proof', 'Transdisciplinarity:',
       'SUMMARY POINTS', '', 'DISCLOSURE STATEMENT',
       'ACKNOWLEDGMENTS']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '3fb05deb-1be3-4bb0-8895-fed15ad64bb5.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                        section_title                                               text
# 0                                           Abstract  A central question in ecology is how individua...
# 1                            I N T R O D U C T I O N  One of the central problems in ecology, biogeo...
# 2  M A T E R I A L S A N D M E T H O D S The species  Tyrannus for®catus is a common breeding migran...
# 3                                Studied individuals  We obtained specimens from the bird collection...
# 4                                          Asymmetry  FA measures the degree of environmental and ge...
# 5                                           Analysis  We used a Mantel test to assess whether FA was...
# 6                                      R E S U L T S  The asymmetry in tail feathers, but not wings ...
# 7                                D I S C U S S I O N  We used DS to investigate whether abundance an...
# ...

# %%
rep = ['Abstract', 
       'INTRODUCTION',
       'MATERIALS AND METHODS The species',
       'Studied individuals',
       'Asymmetry', 
       'Analysis', 
       'RESULTS', 
       'DISCUSSION', 
       'ACKNOWLEDGEMENTS']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '50855997-3d34-4468-8034-a3b4f4a687ac.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Intensively sampled species abundance distribu...
# 1                             I N T R O D U C T I O N  Most species are scarce. Plotting a histogram ...
# 2   M E T H O D S A N D M A T E R I A L S Empirica...  Two empirical datasets were used to test the a...
# 3                                       Regional pool  For both Monte Carlo models I assume a two lev...
# 4                 Model I -unveiling via large sample  In the first simulation, I explore the effect ...
# 5                 Model I -accumulating small samples  In the second set of simulations, I explore th...
# 6   R E S U L T S Model I -unveiling via large sample  As expected, as one increases the sample size ...
# 7             Model II -accumulation of small samples  Under the model of accumulation of small sampl...
# ...

# %%
rep =['Abstract', 'INTRODUCTION',
       'METHODS AND MATERIALS Empirical data',
       'Regional pool', 'Model I -unveiling via large sample',
       'Model I -accumulating small samples',
       'RESULTS Model I -unveiling via large sample',
       'Model II -accumulation of small samples', 'Empirical data',
       'DISCUSSION AND CONCLUSIONS',
       'Relevance of models to empirical data', 'Related work',
       'CONCLUSIONS', 'ACKNOWLEDGEMENTS']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 33

# %%
df[df.result_len == 33]
# Out:
#                                         Id  ... result_len
# 3922  4f665941-71f0-41e8-aecd-5af99ee4aa8a  ...         33
#
# [1 rows x 3 columns]

# %%
f = '4f665941-71f0-41e8-aecd-5af99ee4aa8a.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                      section_title                                               text
# 0                                         Abstract  Potential biomarker detection is a crucial are...
# 1                                     Introduction  Alzheimer's disease (AD) is a complex neurodeg...
# 2              A C C E P T E D M A N U S C R I P T  parameters. In addition, some studies ( [5, 15...
# 3                            Materials and methods
# 4                               Data preprocessing
# 5                Spatial correlations exploitation  We will begin our methods with a brief symbol ...
# 6                                        GS weight  Empirically speaking, the correlation between ...
# 7                                       NLM weight  As the most popular application of the nonloca...
# 8                                 BM3D/BM4D weight  BM3D (for 2-dimensional data in our simulation...
# ...

# %%
rep = ['Abstract', 'Introduction', 'ACCEPTED MANUSCRIPT',
       '', '',
       'Spatial correlations exploitation', 'GS weight', 'NLM weight',
       'BM3D/BM4D weight', 'FVGWAS procedure',
       'ACCEPTED MANUSCRIPT', '',
       'Simulation studies', 'ACCEPTED MANUSCRIPT',
       'Optimal parameters of three weighted functions',
       '', 'Analyses with real data',
       'Conclusions and discussion', 'Conflicts of interest']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 34

# %%
df[df.result_len == 34]
# Out:
#                                         Id  ... result_len
# 2430  a50bb821-b61d-4d79-904a-53b4e93ef9b0  ...         34
# 3436  5ea563d3-aca2-4a31-ae24-5a78a9af7fec  ...         34
#
# [2 rows x 3 columns]

# %%
f = 'a50bb821-b61d-4d79-904a-53b4e93ef9b0.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#      section_title                                               text
# 0                   1. INTRODUCTION .................................
# 1            Sxiii  AUGUST 2017 STATE OF THE CLIMATE IN | d. Net p...
# 2             Sxiv  AUGUST 2017 | APPENDIX 1: Relevant Datasets an...
# 3              Sxv  One of the strongest El Niño events since at l...
# 4               S1  AUGUST 2017 STATE OF THE CLIMATE IN 2016 | 1. ...
# ..             ...                                                ...
# 69  7) Middle eaSt  This region includes Israel, Cyprus, Jordan, L...
# 70         g. Asia  Throughout this section the base periods used ...
# 71          | S212  Downloaded from http://journals.ametsoc.org/do...
# 72          | S215  Hong Kong reported four consecutive days with ...
# 73      h. Oceania  1) overvieW-J. A. renwiCK The climate of the s...
#
# [74 rows x 2 columns]

# %%
rep = ['', '', '', '', '', '', '', 'Global',
       'NASA-GISS HadCRUT4', 'Hydrological cycle', '', '',
       '', 'Earth radiation budget', 'Atmospheric composition',
       'Land surface properties',
       'Measuring and modeling the Martian atmosphere',
       'The Martian Atmosphere', 'The Martian climate in 2016-17',
       'Ocean heat content', 'ERSSTv4', '',
       'Global Ocean Heat Content Trends',
       'CHANGES IN THE NORTHEAST U.S. SHELF ECOSYSTEM AND FISHERIES-J. HARE',
       'DEEP ARGO: SAMPLING THE TOTAL OCEAN VOLUME-N. ZILBERMAN',
       'Surface heat fluxeS', '2) Surface freShwater fluxeS',
       'wInd StreSS', 'long-term perSpectIve',
       'aIr-Sea carbon dIoxIde fluxeS', 'Oceanic cOnditiOns',
       '', '', 'Intertropical convergence zones',
       'Global monsoon summary-B. Wang',
       'Storm tracks and landfalls', 'Atmospheric conditions',
       'Environmental influences on the 2016 season',
       'western nOrth pacific basin-S. J. Camargo (i) Introduction',
       'Seasonal activity', 'TC impacts',
       'nOrth indian Ocean basin-M. C. Kruk',
       'sOuth indian Ocean basin-M. C. Kruk and C. Schreck',
       'Landfalling and other significant TCs',
       'Tropical cyclone heat potential-G. J. Goni, J. A. Knaff, and I-I Lin',
       '', '', 'Indian Ocean dipole-J.-J. Luo',
       '',
       '',
       'ARCTIC OCEAN ACIDIFICATION-J. N. CROSS AND J. T. MATHIS',
       'Climate patterns flipped in', 'Upper ocean', 'deep ocean',
       'observaTional gaps and fUTUre oUTlook', 'North America',
       'Temperature', 'Precipitation',
       'Notable events and impacts', 'South America',
       'Africa', '', 'overvieW',
       'the nordiC and the baltiC CoUntrieS',
       'THE NAKED SHEEP-RAINSTORMS, FLOODS, AND COLD WEATHER CAUSED BY EXTRAORDINARY CYCLONIC ACTIVITY IN MAY/JUNE 2016 IN CENTRAL EUROPE-R. ROLLENBECK, P. BISSOLLI, AND G. VAN DER SCHRIER',
       'THE NAKED SHEEP-RAINSTORMS, FLOODS, AND COLD WEATHER CAUSED BY EXTRAORDINARY CYCLONIC ACTIVITY IN MAY/JUNE 2016 IN CENTRAL EUROPE-R. ROLLENBECK, P. BISSOLLI, AND G. VAN DER SCHRIER',
       'iberian peninSUla', 'eaStern eUrope',
       'Mediterranean and balkan CoUntrieS', 'Middle eaSt',
       'Asia', '', '', 'Oceania']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '5ea563d3-aca2-4a31-ae24-5a78a9af7fec.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                        Introduction  As life expectancy among the American populati...
# 1   The Administration on aging's evidence-based d...  In 2003, the Administration on Aging (AoA) beg...
# 2                    The role of the RE-AIM framework  To be effective and meet predetermined expecta...
# 3                   An emphasis on reach and adoption  While all elements of the RE-AIM Framework are...
# 4                         Participants and procedures  The data collected during this initiative was ...
# 5                                            Measures  To examine personal and neighborhood character...
# 6                                       Data analysis  For the purposes of this study, analyses were ...
# 7                   Nationwide dissemination of CDSMP  Our initial goal is to depict the geographic d...
# ...

# %%
rep = ['Introduction',
       "The Administration on aging's evidence-based disease prevention initiative",
       'The role of the RE-AIM framework',
       'An emphasis on reach and adoption', 'Participants and procedures',
       'Measures', 'Data analysis', 'Nationwide dissemination of CDSMP',
       'Neighborhood characteristics of CDSMP delivery site types',
       'Personal characteristics of CDSMP participants by delivery site type',
       'Delivery site type profiles by neighborhood characteristics',
       'Metro Delivery Site',
       'Participant profiles by personal and neighborhood characteristics',
       'Delivering CDSMP to a diverse set of adults',
       'Limitations and future directions', 'Conclusion']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 35

# %%
df[df.result_len == 35]
# Out:
#                                         Id  ... result_len
# 474   dcf10e8a-3988-41de-8329-30133e3f61e5  ...         35
# 777   ef3e8c03-fa24-411f-97ab-49604f7e8428  ...         35
# 950   ca43e825-ef7e-44ba-b488-f33a9036b589  ...         35
# 1395  c09dbe29-7ada-4fa4-b68e-92e824940967  ...         35
# 1599  c8556731-c602-48c5-a4d8-1d5ecc9312c5  ...         35
# 2315  9a74ff45-e3e5-4145-b20f-ab7377d6ec07  ...         35
# 2339  9b4f2ce6-a5fd-48af-8f89-7f8607746fe1  ...         35
# 2558  7f04db21-3db5-4e7d-8dfe-2263a0cbd016  ...         35
# 2776  89fb285d-f439-436e-b6f2-c988c568173b  ...         35
# 2883  92e7e969-a044-41a9-a70e-850d1f9295e1  ...         35
# 2932  94addacb-ae39-4488-99ef-1d1d3b8f1bd2  ...         35
# 2979  6d3a1370-d2a4-4e11-846e-1bd3949bb5fa  ...         35
# 3113  74472eec-0652-4fbb-b3cc-18ba1fc02923  ...         35
# 3647  67af7dce-a630-4c0b-b099-786262aadd0f  ...         35
# 3844  4b9b0763-39f2-4fd8-adce-31d70c0c5d1b  ...         35
# ...

# %%
f = 'ca43e825-ef7e-44ba-b488-f33a9036b589.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  1. Spatial climate variables are routinely use...
# 1                                        Introduction  Species distribution models (SDMs, Elith & Lea...
# 2             Species distribution modelling and data  In this article, we focus on SDMs fitted using...
# 3   S P A T I A L C L I M A T E V A R I A B L E S ...  PRISM was used to develop grids that reflected...
# 4        Obtaining uncertainty information from PRISM  PRISM interpolation uncertainties were estimat...
# 5   Incorporating uncertainty from spatial climate...  In this section, we discuss two different type...
# 6   C L A S S I C A L V S . B E R K S O N E R R O R S  The two most common types of underlying uncert...
# 7      S I M U L A T I O N -E X T R A P O L A T I O N  Simulation-extrapolation (SIMEX, Cook & Stefan...
# ...

# %%
rep = ['Abstract', 'Introduction',
       'Species distribution modelling and data',
       'SPATIAL CLIMATE VARIABLES DATA',
       'Obtaining uncertainty information from PRISM',
       'Incorporating uncertainty from spatial climate variables into SDMs',
       'CLASSICAL VS . BERKSON ERRORS',
       'SIMULATION EXTRAPOLATION',
       'ADDITIONAL REMARKS ABOUT UTILITY OF ERRORS IN VAR IABLES MODELS',
       'Simulations',
       'BIAS , EFFICIENCY AND PREDICTIVE PERFORMANCE SIMU LATIONS',
       'STATISTICAL POWER SIMULATIONS',
       'PROJECTED CLIMATE CHANGES IMULATIONS',
       'Discussion', 'POSSIBLE EXTENSIONS']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '89fb285d-f439-436e-b6f2-c988c568173b.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  ABSTRACT: Backgro und: Two recent, randomized,...
# 1                                                      Progressive supranuclear palsy (PSP) is a neur...
# 2                               Materials and Methods
# 3                                    Study Population  Raw data were obtained from PSP patients of th...
# 4                                Clinical Assessments  The Schwab & England Activities of Daily Livin...
# 5                                   Image Acquisition  The core MRI protocol for all participants com...
# 6                                Image Processing/ABV  The magnetization prepared rapid gradient echo...
# 7                                Statistical Analysis  Data are given as mean (standard deviation) un...
# ...

# %%
rep = ['Abstract', '', 'Materials and Methods', 'Study Population',
       'Clinical Assessments', 'Image Acquisition',
       'Image Processing/ABV', 'Statistical Analysis', '',
       'Calculation of Standardized Effect Sizes and Sample Sizes',
       '', 'Volumetric Analyses',
       'PSP MRI ATROPHY SCORE', 'Correlation Analysis',
       'Discussion']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '74472eec-0652-4fbb-b3cc-18ba1fc02923.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  There is increasing evidence showing that brai...
# 1                                 M A N U S C R I P T                A C C E P T E D ACCEPTED MANUSCRIPT
# 2                                        Introduction  Alzheimer's disease (AD) is a progressive and ...
# 3                               Materials and methods
# 4                                            Subjects  The dataset used in this study was obtained fr...
# 5                                     MRI acquisition  The MRI data from ADNI and AddNeuroMed were ac...
# 6                                   MRI preprocessing  T1-weighted images were preprocessed using Fre...
# 7                                    Cluster analyses  In total, 162 volume measures (148 cortical an...
# ...

# %%
rep = ['Abstract', 'MANUSCRIPT', 'Introduction',
       '', 'Subjects', 'MRI acquisition',
       'MRI preprocessing', 'Cluster analyses',
       'ACCEPTED MANUSCRIPT', 'Supervised analysis',
       'Statistical analyses', '', 'AD anatomical subtypes',
       'Demographic and clinical characteristics in AD subtypes',
       'Hippocampus to cortex volume ratio', 'Discussion',
       'ACCEPTED MANUSCRIPT',
       'ACCEPTED MANUSCRIPT',
       'ACCEPTED MANUSCRIPT',
       'Acknowledgements', 'MANUSCRIPT ACCEPTED']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = 'dcf10e8a-3988-41de-8329-30133e3f61e5.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                        Introduction  An increasing number of extremely warm summer ...
# 1                                             Methods  Observations of atmosphere and ocean surface t...
# 2                             Atmospheric circulation  Monthly mean sea level pressure (MSLP) and 500...
# 3                       Ocean Sub-Surface Temperature  Depth-longitude profiles of sub-surface temper...
# 4                                     Ocean Modelling  The global ocean model hindcast analysed here ...
# 5                                   Snow and ice data  The end of summer snowline (EOSS) time series ...
# 6                     Managed ecosystems: Viticulture  The phenology of biological systems, including...
# 7                                   Climate scenarios  Observations during the extreme heatwave event...
# ...

# %%
rep = ['Introduction', 'Methods', 'Atmospheric circulation',
       'Ocean Sub-Surface Temperature', 'Ocean Modelling',
       'Snow and ice data', 'Managed ecosystems: Viticulture',
       'Climate scenarios', '',
       'Characteristics of the 2017/18 New Zealand Heatwave',
       'Atmospheric and oceanic circulation anomalies',
       'Analogue seasons', 'Ocean model hindcasts',
       'Accepted Manuscript',
       'Southern Alps Ice Volume and Seasonal Snow', 'Marine ecology',
       'st Century Climate Scenarios Comparison',
       'Discussion and Conclusions']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = 'ef3e8c03-fa24-411f-97ab-49604f7e8428.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Objective: Amyloid positivity is a biomarker o...
# 1                                        Introduction  Hallmark pathologies of Alzheimer's disease (A...
# 2                                             Methods
# 3                 Characteristics of the Study Sample  There were 177 participants from the neuroimag...
# 4                                 ACCEPTED MANUSCRIPT                                             \n\n\n
# 5                 A C C E P T E D M A N U S C R I P T  Compound B (PiB) and structural MRIs occurring...
# 6     Structural Magnetic Resonance Image Acquisition  Scanning was performed on a General Electric S...
# 7   Harmonization of MUSE Anatomical Labels across...
# 8                                 Regions of Interest  First, we examined global regions, i.e., total...
# ...

# %%
rep =['Abstract', 'Introduction', '',
       'Characteristics of the Study Sample', 'ACCEPTED MANUSCRIPT',
       '',
       'Structural Magnetic Resonance Image Acquisition',
       '',
       'Regions of Interest',
       'Amyloid PET Image Acquisition and Processing',
       'Statistical Analyses', 'Sensitivity Analyses', '',
       'Sample Characteristics',
       'Association of PiB+/-Status with Change in Brain Volumes',
       'Sex Differences in Association of PiB+/-Status with Change in Brain Volumes',
       'Sensitivity Analysis', 'Discussion', 'Conclusions']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = 'c09dbe29-7ada-4fa4-b68e-92e824940967.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  A comparison of automated segmentation and man...
# 1                                        Introduction  Brain atrophy is associated with both normal a...
# 2                               Materials and methods
# 3                                        CANVAS study  It is an observational longitudinal case contr...
# 4                                        Participants  We used data from 105 stroke patients (age: 67...
# 5                                     MRI acquisition  Whole brain images were acquired on a 3T Sieme...
# 6                               Hippocampal volumetry  Manual and automated hippocampal volumes for e...
# 7                                      Manual tracing  Hippocampi for the 144 participants were manua...
# ...

# %%
rep = ['Abstract', 'Introduction', '',
       'CANVAS study', 'Participants', 'MRI acquisition',
       'Hippocampal volumetry', 'Manual tracing',
       'ACCEPTED MANUSCRIPT', 'AdaBoost',
       'Atlas-based Hippocampal Segmentation (ABHS)',
       'Computational Anatomy Toolbox (CAT)', 'FIRST-FSL',
       'FreeSurfer', 'FreeSurfer Subfields', 'Lesion masking',
       'Quality control', 'Performance measures',
       'Process yield: Segmentation success rate',
       'Measures of concordance', 'Measures of correlation',
       'Bland-Altman plots', 'Statistical analysis: Control vs. stroke',
       'Methods ranking', 'Results', 'Process yield',
       'Impact of stroke lesion on hippocampal volume estimation',
       'Hippocampal volume distributions',
       'Correlation and concordance of estimated volumes',
       'Control vs. stroke at three months', 'Overall score',
       'Discussion', 'ACCEPTED MANUSCRIPT', 'Conclusion']


df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = 'c8556731-c602-48c5-a4d8-1d5ecc9312c5.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  White Matter Hyperintensities (WMHs) are assoc...
# 1                 A C C E P T E D M A N U S C R I P T  \nimplement different tests to assess cognitio...
# 2                                       Introduction:  While Parkinson's disease (PD) is typically ch...
# 3                                            Methods:  Patients: The Parkinson's Progression Markers ...
# 4                                 ACCEPTED MANUSCRIPT                                           \n\n\n\n
# 5                               Statistical Analysis:  We tested two major hypotheses: (1) greater WM...
# 6                                            Results:
# 7   A C C E P T E D M A N U S C R I P T Baseline W...  Based on Litvan's criteria for cognitive statu...
# ...

# %%
rep = ['Abstract', 'ACCEPTED MANUSCRIPT', 'Introduction',
       '', '', 'Statistical Analysis',
       '',
       'ACCEPTED MANUSCRIP T Baseline WMHL as a Predictor of Longitudinal Cognition',
       'Survival Analysis', 'Mixed-Effects Modelling',
       'Voxel-wise Analysis', 'Discussion:', '']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '9a74ff45-e3e5-4145-b20f-ab7377d6ec07.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Please cite this article as: F. Bartel, M. Vis...
# 1                                        Introduction  The hippocampus is a small cortical structure ...
# 2                 A C C E P T E D M A N U S C R I P T  hippocampal atrophy rates have been measured p...
# 3                               Materials and Methods
# 4                      Datasets and image acquisition  In this study we determined hippocampal volume...
# 5                                    Training dataset  Training data consisted of a small subset (N=1...
# 6                                  Validation dataset  This dataset is the same dataset as used by [M...
# 7                            Hippocampus segmentation  Manual hippocampus segmentation (only validati...
# 8                                 ACCEPTED MANUSCRIPT
# ...

# %%
rep =['Abstract', 'Introduction', 'ACCEPTED MANUSCRIPT',
       '', 'Datasets and image acquisition',
       'Training dataset', 'Validation dataset',
       'Hippocampus segmentation', '',
       'Multi-atlas label fusion segmentation (both datasets)',
       'Non-linear registration methods (both datasets)',
       'Surface reconstruction and mesh deformation', 'Analysis',
       '', 'Consistency checks with the training dataset',
       'Consistency checks with the validation dataset', 'Discussion',
       'Clinical applicability', 'Conclusion']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '9b4f2ce6-a5fd-48af-8f89-7f8607746fe1.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                           section_title                                               text
# 0   A C C E P T E D M A N U S C R I P T  A C C E P T E D M A N U S C R I P T\n\nMR scan...
# 1                          INTRODUCTION  The diagnosis of Alzheimer's disease (AD) can ...
# 2                               METHODS
# 3                          Participants  We used the structural brain MRI scans from th...
# 4              MRI acquisition protocol  Details about the ADNI MRI data acquisition pr...
# 5                   ACCEPTED MANUSCRIPT  A C C E P T E D M A N U S C R I P T transforma...
# 6         Convolutional neural networks  Mimicking how the human brain processes inform...
# 7                           Experiments  Performance of the 3D CNN was validated and te...
# 8                               RESULTS  A C C E P T E D M A N U S C R I P T sensitivit...
# 9                            DISCUSSION  Effective and accurate AD diagnosis is critica...
# ...

# %%
rep = ['ACCEPTED MANUSCRIPT', 'INTRODUCTION', '',
       'Participants', 'MRI acquisition protocol', 'ACCEPTED MANUSCRIPT',
       'Convolutional neural networks', 'Experiments', '',
       'DISCUSSION', 'Acknowledgment']

df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '7f04db21-3db5-4e7d-8dfe-2263a0cbd016.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract   The visual identification of atrophy is most...
# 1                 A C C E P T E D M A N U S C R I P T  3 characteristics to prevalences typically fou...
# 2                                        Introduction  The accuracy of MRI-based diagnostics of neuro...
# 3                                             Methods
# 4                                          Study Data  Structural MRI from 120 subjects † (30 HC, 30 ...
# 5                                   Image Acquisition  Sagittal T1-weighted 3D magnetization prepared...
# 6                                     Data Processing  All T1 weighted images were processed identica...
# 7   Estimation of normalized local GM/CSF volumes ...  At every voxel of each individual, we computed...
# ...

# %%
rep = ['Abstract', 'ACCEPTED MANUSCRIPT', 'Introduction',
       '', 'Study Data', 'Image Acquisition', 'Data Processing',
       'Estimation of normalized local GM/CSF volumes and display of GM/CSF atrophy indices',
       'Reading',
       'Evaluation of the added value of displaying computer assisted atrophy reading',
       'Usefulness of atrophy scores alone', '', 'Discussion']

df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '89fb285d-f439-436e-b6f2-c988c568173b.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  ABSTRACT: Backgro und: Two recent, randomized,...
# 1                                                      Progressive supranuclear palsy (PSP) is a neur...
# 2                               Materials and Methods
# 3                                    Study Population  Raw data were obtained from PSP patients of th...
# 4                                Clinical Assessments  The Schwab & England Activities of Daily Livin...
# 5                                   Image Acquisition  The core MRI protocol for all participants com...
# 6                                Image Processing/ABV  The magnetization prepared rapid gradient echo...
# 7                                Statistical Analysis  Data are given as mean (standard deviation) un...
# ...

# %%
rep = ['Abstract', '', '', 'Study Population',
       'Clinical Assessments', 'Image Acquisition',
       'Image Processing/ABV', 'Statistical Analysis', 'FIG. 1.',
       'Calculation of Standardized Effect Sizes and Sample Sizes',
       '', 'Volumetric Analyses',
       'PSP MRI ATROPHY SCORE', 'Correlation Analysis',
       'Discussion']

df1.text.replace(r'\bP S P M R I A T R O P H Y S C O R E\b',
                     'PSP MRI ATROPHY SCORE', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '92e7e969-a044-41a9-a70e-850d1f9295e1.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Background: Alzheimer's disease (AD) is a prog...
# 1                                        Introduction  Alzheimer's disease (AD) is a progressive neur...
# 2                                Method and Materials  All data were obtained from the Alzheimer's Di...
# 3                                        Participants  Full eligibility criteria for the ADNI are des...
# 4                                   Image Acquisition  MRI data were downloaded from the ADNI2 databa...
# 5                                     Image analysis.  FA maps were created using DTIfit and input in...
# 6                            Statistical comparisons.  Within-group comparisons were made for individ...
# 7                                             Results
# ...

# %%
rep =['Abstract', 'Introduction', 'Method and Materials', 'Participants',
       'Image Acquisition', 'Image analysis.', 'Statistical comparisons.',
       '',
       'Within-group Microstructural White Matter Changes in Individuals with AD and Healthy Controls at Baseline and Year One',
       'ACCEPTED MANUSCRIPT', '',
       '',
       'Between-group Differences in Individuals with AD and Healthy Controls at Baseline and Year One',
       '', '', '', 'Discussion',
       '', 'Conclusion']

df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '94addacb-ae39-4488-99ef-1d1d3b8f1bd2.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                        section_title                                               text
# 0                                           Abstract  The value of 18 F-fluorodeoxyglucose (FDG) PET...
# 1                                       Introduction  In recent years, the prognostic accuracy of 18...
# 2                                ACCEPTED MANUSCRIPT                                           \n\n\n\n
# 3                A C C E P T E D M A N U S C R I P T  knowledge about typical AD patterns. The predi...
# 4                              Materials and Methods
# 5                                           Subjects  The data used in the present study is provided...
# 6               FDG PET data and image preprocessing  The scans were acquired at 57 different sites ...
# 7                      Region of interest derivation  Two fundamentally different methods were appli...
# ...

# %%
rep =['Abstract', 'Introduction', '',
       'ACCEPTED MANUSCRIPT', 'Materials and Methods',
       'Subjects', 'FDG PET data and image preprocessing',
       'Region of interest derivation',
       'Cox regressions in the test dataset', 'Results',
       'ACCEPTED MANUSCRIPT Discussion', 'Conclusions']

df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '6d3a1370-d2a4-4e11-846e-1bd3949bb5fa.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Major depression, currently the world's primar...
# 1                                                      Exploring the neurobiological effects of ECT i...
# 2                                        Introduction  Depressive disorders are now the single leadin...
# 3                 A C C E P T E D M A N U S C R I P T  6\nThe first of such MRI-studies appeared in t...
# 4                                             Methods
# 5              A C C E P T E D M A N U S C R I P T 11  The methods for setting up the GEMRIC included...
# 6                                             Results
# 7                           Forming the collaboration  After identifying potential contributors to th...
# 8   MRI data, clinical measures and common sample ...  A prerequisite for participating in the GEMRIC...
# ...

# %%
rep = ['Abstract', '', 'Introduction',
       'ACCEPTED MANUSCRIPT', '',
       'ACCEPTED MANUSCRIPT', '',
       'Forming the collaboration',
       'MRI data, clinical measures and common sample characteristics',
       '',
       'Ethical, practical and technical challenges in forming the collaboration',
       'Measures to ensure patient integrity',
       'ACCEPTED MANUSCRIPT',
       'Common server and secure data storage',
       'Structural imaging preprocessing, FreeSurfer and Quarc analysis',
       '', 'GEMRIC projects']

df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '67af7dce-a630-4c0b-b099-786262aadd0f.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Alzheimer's disease (AD) is characterized by a...
# 1                                        Introduction  Alzheimer's disease (AD) is a chronic neurodeg...
# 2                                 ACCEPTED MANUSCRIPT  \nA C C E P T E D M A N U S C R I P T 6 order ...
# 3                 A C C E P T E D M A N U S C R I P T  5\nLongitudinal studies comparing cerebral atr...
# 4                                Material and methods
# 5                                            Subjects  In this work, we have studied and compared two...
# 6        Evaluation of the equivalence of the samples  Visual inspection of images seemed to point to...
# 7                                Image pre-processing  Longitudinal changes were evaluated by means o...
# ...

# %%
rep = ['Abstract', 'Introduction', 'ACCEPTED MANUSCRIPT',
       'ACCEPTED MANUSCRIPT', '',
       'Subjects', 'Evaluation of the equivalence of the samples',
       'Image pre-processing', 'Statistical analyses of images',
       'Sample sizes', '', '',
       '(Insert table 1 and figure 1 approximately here)',
       'Longitudinal VBM',
       'ACCEPTED MANUSCRIPT (Insert Figure 4 and table 5 approximately here)',
       '', '', 'Discussion',
       'Conclusions', 'Acknowledgments']


df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '4b9b0763-39f2-4fd8-adce-31d70c0c5d1b.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                                                    A C C E P T E D M A N U S C R I P T
# 1                                        INTRODUCTION  Quantitative methods to extract specific and s...
# 2                                 ACCEPTED MANUSCRIPT  A C C E P T E D M A N U S C R I P T 5 and (e) ...
# 3                               MATERIALS AND METHODS
# 4                                         Participant  A Single Individual volunteering for Multiple ...
# 5                               Participating studies  Several organizations and projects have contri...
# 6                    Image acquisition and processing  For the present study, 86 SIMON scans (nine on...
# 7                                Statistical analyses  To verify whether following CDIP parameters re...
# 8                                             RESULTS
# ...

# %%
rep = ['', 'INTRODUCTION', 'ACCEPTED MANUSCRIPT', '',
       'Participant', 'Participating studies',
       'Image acquisition and processing', 'Statistical analyses',
       '', 'Parameter compliance',
       'Impact of parameter compliance on morphometric variance value',
       '', '',
       '',
       'ACCEPTED MANUSCRIPT', 'DISCUSSION', 'Strengths',
       'Limitations', 'CONCLUSIONS']

df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '5517804f-6653-4bfe-998f-7ce7f0c694d0.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Background: Grey matter (GM) atrophy in Alzhei...
# 1                                        Introduction  Alzheimer's disease (AD) is a neurodegenerativ...
# 2                                 ACCEPTED MANUSCRIPT  A C C E P T E D M A N U S C R I P T Good et al...
# 3                                  Material & Methods
# 4                                        Participants  Data used in the preparation of this article w...
# 5                 A C C E P T E D M A N U S C R I P T  We used repeated MMSE as a measure for general...
# 6                  Image Acquisition & Pre-Processing  Image acquisition details and initial preproce...
# 7                                  PET / CSF analysis  Participants were classified as having normal ...
# ...

# %%
rep = ['Abstract', 'Introduction', 'ACCEPTED MANUSCRIPT',
       '', 'Participants',
       'ACCEPTED MANUSCRIPT',
       'Image Acquisition & Pre-Processing', 'PET / CSF analysis',
       'Statistical analyses',
       '', '',
       'Sample Description', '',
       'Changes in grey matter volumes and MMSE as a function of time',
       'Changes in grey matter volumes and MMSE as a function of aging',
       'Changes in grey matter volumes as a function of time, aging and MMSE in individuals with normal amyloid',
       'Discussion',
       'Future research should further investigate this question by studying how GM atrophy relates',
       'Conclusion']

df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '59a3397e-8509-4d01-a471-345b9dd2fd60.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  The medial temporal lobe atrophy (MTA) and the...
# 1                                                                    A C C E P T E D M A N U S C R I P T
# 2                                        Introduction  In Alzheimer's disease (AD), neurodegeneration...
# 3                 A C C E P T E D M A N U S C R I P T  6 Different age-corrected cutoffs distinguishi...
# 4                               Materials and Methods
# 5                         Study population and design  We collected data from the "Italian Brain Norm...
# 6                          Magnetic resonance imaging
# 7                                 ACCEPTED MANUSCRIPT  A C C E P T E D M A N U S C R I P T 9 MRI scan...
# 8                                       Visual rating  Based on Scheltens' original description (Sche...
# ...

# %%
rep = ['Abstract', '', 'Introduction',
       'ACCEPTED MANUSCRIPT', '',
       'Study population and design', '',
       'ACCEPTED MANUSCRIPT', 'Visual rating', 'Genetic analysis',
       'Statistical analyses', '',
       'Demographic and clinical features', 'Inter-rater reliability',
       'Normative data',
       'Effects of clinical features and APOE-ε4 on atrophy severity',
       'Discussion', '', 'Funding',
       'Legends:', 'Legend:', '']

df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '57e45794-05e7-4ae0-a729-0d60bea014e0.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  The clinical presentation of Alzheimer's disea...
# 1                                        Introduction  Alzheimer's disease (AD), the most common form...
# 2                                Material and methods
# 3                                            Overview  We performed the following analyses on fractio...
# 4                                                Data  Data used in preparation of this article were ...
# 5                 A C C E P T E D M A N U S C R I P T  For neuropsychological data, memory (ADNI-Mem)...
# 6               Tract-Based Spatial Statistics (TBSS)  DTI scans help us understand the regional basi...
# 7                   Latent Dirichlet Allocation (LDA)  In this study, our premise is that an individu...
# ...

# %%
rep = ['Abstract', 'Introduction', '', 'Overview',
       'Data', 'ACCEPTED MANUSCRIPT',
       'Tract-Based Spatial Statistics (TBSS)',
       'Latent Dirichlet Allocation (LDA)',
       'Choosing the number K of factors',
       'Evaluating the longitudinal stability of latent factors',
       'Modelling the longitudinal cognitive decline using latent WM impairment factors',
       'Association of APOE genotype with WM impairment factors',
       'Implementation details', '', 'Overall Approach',
       'WM Impairment Factors in AD',
       'The stability of latent factors as AD progresses',
       'Factor compositions of participants at baseline. Each dot corresponds to a participant and its location represents his/her factor composition. Corners of this triangle',
       '',
       'Association between WM Impairment factors and cognition',
       'Association between APOE genotype and latent factors',
       'Discussion', 'WM impairment factors in AD',
       'Factor compositions were stable as the disease progresses',
       'Factors reflect distinct association with longitudinal cognitive decline',
       'APOE genotype was associated with latent factors', 'Limitations',
       'Conclusions']

df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '28da23ba-99b7-4231-8cb3-c80d60dfd822.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Please cite this article as: C.-Y. Wee, C. Liu...
# 1                                        Introduction  Alzheimer's disease (AD) is clinically charact...
# 2                 A C C E P T E D M A N U S C R I P T  4 despite the high classification accuracy, mu...
# 3                                 ACCEPTED MANUSCRIPT  A C C E P T E D M A N U S C R I P T 5 cortical...
# 4                               Materials and Methods
# 5                                            Datasets  ADNI Cohorts 3 . This study included 1083 and ...
# 6                   MRI Data Acquisition and Analysis  ADNI-1 and ADNI-2 Cohorts. Structural T 1 -wei...
# 7                       Cortical Graph Neural Network  Mathematically, cortical thickness is a functi...
# ...

# %%
rep = ['Abstract', 'Introduction', 'ACCEPTED MANUSCRIPT',
       'ACCEPTED MANUSCRIPT', '', 'Datasets',
       'MRI Data Acquisition and Analysis',
       'Cortical Graph Neural Network',
       'Generalization from ADNI-2 to ADNI-1 Cohort',
       'MCI, and MCI vs. AD classifications.',
       'Transfer Learning from the ADNI-2 to the Asian Cohort',
       'Evaluation Measures',
       'Most Discriminating Brain Regions Based on Cortical Thickness',
       '', 'ACCEPTED MANUSCRIPT',
       '',
       'Comparison with Multilayer', '',
       'Prediction of MCI to AD Conversion.',
       '',
       'Transfer Learning of the Graph-CNN to the Asian Cohort',
       '', 'Discussion',
       'Conclusions']

df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '25b06a55-f82c-4332-a4db-e84a79f2c18f.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  In both samples, individuals whose CAQ profile...
# 1   A C C E P T E D M A N U S C R I P T ACCEPTED M...  , who independently created theory-derived slo...
# 2                                             Study 1  Study 1 used periodic brief audio recordings f...
# 3                                             Methods                                                 \n
# 4   Participants and audio recording collection pr...  Ninety-two students (55.4% female, M ± SD = 20...
# 5                                Self-report measures  After returning the iPod and before receiving ...
# 6                                 ACCEPTED MANUSCRIPT  Relationships. The eighth ALHB scale, the Mini...
# 7                California adult Q-sort (CAQ) rating  The California Adult Q-Sort, or Q-Set (CAQ: Bl...
# ...

# %%
rep = ['Abstract',
       'ACCEPTED MANUSCRIPT',
       '', '',
       'Participants and audio recording collection procedure',
       'Self-report measures', 'ACCEPTED MANUSCRIPT',
       'California adult Q-sort (CAQ) rating', '', '',
       'Descriptive statistics', 'Validation of CAQ-based FFM scores',
       '',
       '',
       'CAQ Extraversion-and Openness-loading items and CAQ-based slow LHS',
       'HEXACO Extraversion and Openness facets and Life History measures',
       'ALHB, personality dimensions, and CAQ-based slow LHS', '',
       'Participants and CAQ profile sources', 'General Discussion',
       'Acknowledgments']

df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '29fbeb8a-12f3-47e8-85a4-8a6f1e0a4771.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Please cite this article as: C. Wang, L. Zhao,...
# 1                                        Introduction  The subcortical infarction generally causes im...
# 2                 A C C E P T E D M A N U S C R I P T  this method has been reported with lower accur...
# 3                                              Method  Subjects MRI data were collected by two scanne...
# 4                                   Image acquisition  Two 3.0-Tesla MR imaging system from two Disco...
# 5                                    Image processing  The analyses of image processing were performe...
# 6                                Statistical analyses  Group comparison of brain regional volumetry\n...
# 7         Brain volumetry-based structural covariance  As most studies that investigated structural c...
# ...

# %%
rep = ['Abstract', 'Introduction', 'ACCEPTED MANUSCRIPT',
       'Method', 'Image acquisition', 'Image processing',
       'Statistical analyses',
       'Brain volumetry-based structural covariance',
       'Associations of brain volumetric measures with motor function after stroke',
       '', 'Demographic and clinical parameters',
       'Group comparison of brain regional volumetry', 'Discussion',
       'ACCEPTED MANUSCRIPT']

df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '349ffd40-e754-4a76-bf24-310ea6473b0e.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  s Disease Neuroimaging Initiative , Left later...
# 1                                                      *Data used in preparation of this article were...
# 2                                        Introduction  Alzheimer's disease (AD) is the most common ca...
# 3                                 ACCEPTED MANUSCRIPT                                             \n\n\n
# 4                 A C C E P T E D M A N U S C R I P T  lateralized longitudinal patterns of neurodege...
# 5                                Subjects and Methods
# 6                                            Subjects  Participant data for this study were drawn fro...
# 7                                 Clinical evaluation  For each subject, cognitive function was evalu...
# ...

# %%
rep = ['Abstract', '', 'Introduction', '',
       'ACCEPTED MANUSCRIPT', '',
       'Subjects', 'Clinical evaluation', 'Imaging Procedures', '',
       'Subject characteristics and cognitive performance',
       'Delayed Word Recall, Word Recall, Word Recognition (all dementia-AD>MCI-AD>CU) and',
       '24-month rCMRgl declines',
       'Associations of 24-month rCMRgl declines with cognitive decline',
       'Discussion', 'Conclusion', '']


df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '163f80d6-b5cb-41fa-8d06-49b7df55b8a9.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Please cite this article as: H. Jang, J. Park,...
# 1                                                      A C C E P T E D M A N U S C R I P T 4 biomarke...
# 2                                        Introduction  Mild cognitive impairment (MCI) is considered ...
# 3                                             Methods
# 4                                  Study participants  We used the Alzheimer's Disease Neuroimaging I...
# 5                 A C C E P T E D M A N U S C R I P T  8\nIn this study, we included MCI patients who...
# 6                            Clinical data collection  Basic demographics and clinical data were extr...
# 7                                Statistical analysis  For model construction, we randomly divided th...
# 8                                 ACCEPTED MANUSCRIPT
# ...

# %%
rep = ['Abstract', '', 'Introduction', '', 'Study participants',
       'ACCEPTED MANUSCRIPT', 'Clinical data collection',
       'Statistical analysis', '', '',
       'Differences in clinical characteristics of fast and slow decliners',
       'Nomograms as prediction models',
       'Comparison with prediction models including different combinations of biomarkers',
       'Discussion', 'Conclusions', '']

df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '1b6d53b1-7631-42e7-a44c-cf76bd91ca65.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Denmark d Data used in preparation of this art...
# 1   A C C E P T E D M A N U S C R I P T 1 Introduc...  The segmentation of medical images gives quant...
# 2                 A C C E P T E D M A N U S C R I P T  intensity-normalization techniques such as ran...
# 3                                 ACCEPTED MANUSCRIPT  A C C E P T E D M A N U S C R I P T thalamus, ...
# 4                                Material and Methods  This section describes the proposed method and...
# 5                        Feature-Space Transformation
# 6                                            Say that  In our experiments, we train only on images fr...
# 7                            Hippocampus Segmentation  The hippocampus segmentation was performed by ...
# ...

# %%
rep = ['Abstract', 'ACCEPTED MANUSCRIPT Introduction',
       'ACCEPTED MANUSCRIPT', 'ACCEPTED MANUSCRIPT',
       'Material and Methods', '', '',
       'Hippocampus Segmentation', 'Multi-Atlas Probability', 'Features',
       'Classification', 'Data', 'Preprocessing', '',
       '', 'Experiments', 'Compared Methods',
       '', '', '', '', '',
       '',
       '',
       '', 'Quantitative Results',
       'Influence of k and N', 'Computational Cost',
       '', 'Conclusion',
       'Comparison with Other Methods', 'Related Work',
       'Features Used for FST', 'Limitations and Future Work',
       '']

df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '1f65d884-e1a8-4894-94a9-5cb7f4e75dc5.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  volume reduction of the cholinergic forebrain ...
# 1                                        Introduction  The research focus of early disease detection ...
# 2                 A C C E P T E D M A N U S C R I P T  4 temporoparietal hypometabolism frequently ob...
# 3                               Materials and Methods
# 4                                        Participants  Individuals with SCD (n=24) were recruited by ...
# 5      Standard protocol approval and patient consent  The study protocol was approved by the ethics ...
# 6             Experimental neuropsychological battery  The neuropsychological test battery was design...
# 7                                                 MRI  Structural data were obtained from 24 SCD subj...
# ...

# %%
rep = ['Abstract', 'Introduction', 'ACCEPTED MANUSCRIPT',
       '', 'Participants',
       'Standard protocol approval and patient consent',
       'Experimental neuropsychological battery', 'MRI',
       'Preprocessing of MRI data',
       'Volumetry of the cholinergic basal forebrain nuclei', '',
       'Preprocessing of FDG-PET data', '',
       "Participants' characteristics and neuropsychological data at baseline",
       'Modeling of the trajectories of memory performance',
       'Group comparison of the cholinergic forebrain nuclei volumes',
       'ACCEPTED MANUSCRIPT',
       'Exploratory correlation analysis between chBFN volumes and BDI-scores',
       'Correlation analysis between chBFN volumes and local GM volume',
       'Correlation analysis between chBFN volumes and FDG PET',
       '', 'Participant characteristics',
       'ChBFN-volume group differences',
       'Memory performance and correlation with chBFN-volumes',
       'Discussion', 'ACCEPTED MANUSCRIPT',
       'Limitations', 'ACCEPTED MANUSCRIPT',
       'Conclusion',
       'Correlation between the Ch4p volume and glucose metabolism']


df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '2639494d-aed7-469a-a38a-972bb2cc1e94.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Validating sensitive markers of hippocampal de...
# 1                                        Introduction  Alzheimer's disease (AD) is the most common ca...
# 2                                 ACCEPTED MANUSCRIPT  A C C E P T E D M A N U S C R I P T neurodegen...
# 3                                             Methods
# 4                                            Subjects  Imaging data for the current study were obtain...
# 5                                    Data Acquisition  The Search Criteria used to acquire data ident...
# 6                                  Imaging Processing  For each subject, all baseline raw diffusion w...
# 7                                     APOE Genotyping  Samples were genotyped for the APOE ε2, ε3 and...
# ...

# %%
rep = ['Abstract', 'Introduction', 'ACCEPTED MANUSCRIPT', '',
       'Subjects', 'Data Acquisition', 'Imaging Processing',
       'APOE Genotyping', 'CSF Analysis', 'Region of Interest Analyses',
       '', 'Correlational Analyses',
       'Demographics and Clinical Data', '',
       'ACCEPTED', 'Volumetric Analyses', 'Correlation Analyses',
       'ACCEPTED MANUSCRIPT', 'Discussion',
       'Previous studies have shown correlations between cognitive measures and volumetric']

df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '0f50c532-2ad7-41d0-9f7c-b0918fb1f39d.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                    section_title                                               text
# 0                                       Abstract  Classifying neurodegenerative brain diseases i...
# 1                                   Introduction  1 Over the last two decades, Magnetic Resonanc...
# 2            A C C E P T E D M A N U S C R I P T  \n\n\n\n\n\n\nACCEPTED MANUSCRIPT classificati...
# 3                            ACCEPTED MANUSCRIPT  The situation in classifying MRI data is stark...
# 4                  The Scattering Representation  The introduced paradigm consists of two princi...
# 5                       The 3D Wavelet Transform  We will first review the wavelet transform, be...
# 6                       The Scattering Transform  The 3D scattering transform is computed as a s...
# 7               Linearization of Diffeomorphisms  In brain morphometry studies, the differences ...
# ...

# %%
rep = ['Abstract', 'Introduction', 'ACCEPTED MANUSCRIPT',
       'ACCEPTED MANUSCRIPT', 'The Scattering Representation',
       'The 3D Wavelet Transform', 'The Scattering Transform',
       'Linearization of Diffeomorphisms',
       'Visualization of the 3D Scattering Transform', 'Experiments',
       'AGEhIV Dataset', 'OASIS Alzheimer Dataset', 'ADNI Database',
       'Experiments on a Subset of Data',
       'Experiments on a Bigger Sample Size', '',
       'Discussion and Conclusion', 'Highlights']

df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 37

# %%
df[df.result_len == 37]
# Out:
#                                         Id  ... result_len
# 1105  dbf64946-04c2-4dad-bfd4-89ff39a1d398  ...         37
# 2963  9283ad11-b09b-4c3c-93db-62b7e4bf68ac  ...         37
#
# [2 rows x 3 columns]

# %%
f = 'dbf64946-04c2-4dad-bfd4-89ff39a1d398.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                  section_title                                               text
# 0                                     Abstract  Large-scale comparisons of patients and health...
# 1        r e v i e w n e u r o g e n o m i c s  Worldwide consortia offer new opportunities fo...
# 2                              GWAS of imaging  For neurological diseases, a few common geneti...
# 3                          Data harmonization.  To amass the largest possible sample, data fro...
# 4   Biological interpretation of GWAS results.  After identifying significant genetic effects,...
# 5                      Multiple-testing issues  As genome-wide approaches to genetic analysis ...
# 6                              How many tests?  Whole-genome analyses of whole-brain images in...
# 7                        Power and replication  Replication is vital to verify association sig...
# 8                   How much power do we have?  Methods exist to compute how many subjects are...
# ...

# %%
rep = ['Abstract', 'review neurogenomics',
       'GWAS of imaging', 'Data harmonization.',
       'Biological interpretation of GWAS results.',
       'Multiple-testing issues', 'How many tests?',
       'Power and replication', 'How much power do we have?',
       'Do discoveries generalize?', 'Dimension reduction.',
       'Neurogenetic syndromes.', 'Recommendations', 'Conclusion']

df1.text.replace(r'\br e v i e w n e u r o g e n o m i c s\b',
                     'review neurogenomics', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '9283ad11-b09b-4c3c-93db-62b7e4bf68ac.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                        section_title                                               text
# 0                                           Abstract  Context Docosahexaenoic acid (DHA) is the most...
# 1              D O C O S A H E X A E N O I C A C I D  (DHA) is an omega-3 fatty acid identified as a...
# 2                                            METHODS  This randomized, double-blind, placebo-control...
# 3         Study Medication, Assignments, and Masking  The study drug was an algal-derived DHA (Marte...
# 4                                   Outcome Measures  The2co-primaryoutcomemeasureswere the rate of ...
# 5                               Statistical Analysis  The primary aim of the statistical analysis wa...
# 6                                            RESULTS  Participants were recruited between February a...
# 7   Plasma and Cerebrospinal Fluid Fatty Acid Levels  As expected, plasma phospholipid DHA increased...
# ...

# %%
rep = ['Abstract', 'DOCOSAHEXAENOIC ACID, DHA', 'METHODS',
       'Study Medication, Assignments, and Masking', 'Outcome Measures',
       'Statistical Analysis', 'RESULTS',
       'Plasma and Cerebrospinal Fluid Fatty Acid Levels',
       'Co-primary Outcome Measures', 'Secondary Outcome Measures',
       'Adverse Events', 'Blinding Analysis', 'Subgroup Analyses',
       'COMMENT']

df1.text.replace(r'\bD O C O S A H E X A E N O I C A C I D\b',
                     'DOCOSAHEXAENOIC ACID, DHA', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 40

# %%
df[df.result_len == 40]
# Out:
#                                         Id  ... result_len
# 4754  28388d72-2fec-4be5-8a89-af5c6b10a192  ...         40
#
# [1 rows x 3 columns]

# %%
f = '28388d72-2fec-4be5-8a89-af5c6b10a192.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                                      xpendable bathythermographs (XBTs) are probes ...
# 1                                                 926                                          JUNE 2016
# 2                                                   |  Since a large number of available XBT metadata...
# 3                        MINIMUM REQUIREMENTS FOR XBT  METADATA. In addition to the standard requirem...
# 4   C U R R E NT X BT B I A S CO R R ECTI O N SCHE...  A suite of correction schemes for global histo...
# 5          B I A S -C O R R E C T E D X B T D A T A :  APPLICATIONS. XBT data have been widely used i...
# 6                                  F UTU R E WO R K .  Extensive progress has been made during the pa...
# 7                                                 929  JUNE 2016 AMERICAN METEOROLOGICAL SOCIETY | is...
# ...

# %%
rep = ['', '', '', 'MINIMUM REQUIREMENTS FOR XBT',
       'CURRENT XBT BIAS CORRETION SCHEMES',
       'BIAS CORRECTED XBT DATA', 'FUTURE WORK',
       '', 'SUMMARY.', '', 'ACKNOWLEDGMENTS.']

rep_dict = {
    r'\bC U R R E NT X BT B I A S CO R R ECTI O N SCHEMES\b':'MINIMUM REQUIREMENTS FOR XBT',
    r'\bB I A S -C O R R E C T E D X B T D A T A\b':'CURRENT XBT BIAS CORRETION SCHEMES',
    r'\bF UTU R E WO R K\b':'FUTURE WORK'
}
for (k, v) in rep_dict.items():
    df1.text.replace(k, v, regex=True, inplace = True)

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 41

# %%
df[df.result_len == 41]
# Out:
#                                         Id  ... result_len
# 2722  8d45dbf3-9490-4914-aed8-e1a7c0628071  ...         41
#
# [1 rows x 3 columns]

# %%
f = '8d45dbf3-9490-4914-aed8-e1a7c0628071.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                        section_title                                               text
# 0                                                     comprised 83% of biomedical PhDs awarded in 20...
# 1      Incidence and duration of biomedical postdocs  The number of scientists with biomedical PhDs ...
# 2                    Shulamit Kahn & Donna K Ginther  While postdocs are necessary for entry into te...
# 3                                 Data and variables  We used biennial longitudinal data from the 19...
# 4  Factors associated with starting in postdoctor...  We used a probit model to examine the factors ...
# 5          C A R E E R S A N D R E C R U I T M E N T  measuring the field-specific change in industr...
# 6                                       Implications  When providing prescriptions for what ails bio...
# 7                         Summary and interpretation

# %%
rep = ['', 'Incidence and duration of biomedical postdocs',
       'Shulamit Kahn & Donna K Ginther', 'Data and variables',
       'Factors associated with starting in postdoctoral positions',
       'CAREERS AND RECRUITMENT', 'Implications',
       '']


df1.text.replace(r'\bC A R E E R S A N D R E C R U I T M E N T\b',
                     'CAREERS AND RECRUITMENT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ##42

# %%
df[df.result_len == 42]
# Out:
#                                         Id  ... result_len
# 5920  15263885-391e-4031-9f3c-35a0086ab21d  ...         42
#
# [1 rows x 3 columns]

# %%
f = '15263885-391e-4031-9f3c-35a0086ab21d.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Bayesian networks are a type of probabilistic ...
# 1                                        INTRODUCTION  A Bayesian network (BN) (Pearl, 1988; Koller a...
# 2                                   BAYESIAN NETWORKS
# 3                                          DEFINITION  BNs (Pearl, 1988; Koller and Friedman, 2009) a...
# 4      p(x|y, z) = p(x|z) ∀x, y, z values of X, Y, Z,  that is, whenever Z = z, the information Y = y...
# 5   p(x, y|z) = p(x|z)p(y|z) ∀x, y, z values of X,...  Conditional independence is halfway between th...
# 6   p(A, N, S, D, W) = p(A)p(N|A)p(S|A)p(D|N, S)p(...  Thus, the JPD p(A, N, S, D, W) requires 2 5 − ...
# 7                             A-N-S-D-W or A-S-W-N-D.  Other conditional independences may be derived...
# ...

# %%
rep = ['Abstract', 'INTRODUCTION', 'BAYESIAN NETWORKS', 'DEFINITION',
       '',
       '',
       '',
       '', 'GAUSSIAN BAYESIAN NETWORKS',
       'DYNAMIC BAYESIAN NETWORKS', '',
       'WHAT IS INFERENCE?',
       '',
       'INFERENCE METHODS', 'LEARNING BAYESIAN NETWORKS FROM DATA',
       'LEARNING BAYESIAN NETWORK PARAMETERS',
       'LEARNING BAYESIAN NETWORK STRUCTURES. ASSOCIATIONS',
       'Constrained-based methods', 'Score and search methods',
       'LEARNING BAYESIAN NETWORK STRUCTURES. SUPERVISED CLASSIFICATION',
       'Discrete Bayesian network classifiers',
       'Continuous Bayesian network classifiers',
       'LEARNING BAYESIAN NETWORKS STRUCTURES. CLUSTERING',
       '', 'MORPHOLOGICAL DATA',
       'ELECTROPHYSIOLOGICAL DATA',
       'GENOMICS, PROTEOMICS, AND TRANSCRIPTOMICS', 'NEUROIMAGING DATA',
       'fMRI', '', '', '', 'Multimodal neuroimaging',
       'DISCUSSION']
    
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 43

# %%
df[df.result_len == 43]
# Out:
#                                         Id  ... result_len
# 4175  59ceea9a-be62-4d3e-82cd-eeba5135a70e  ...         43
# 5988  14a8b313-7c91-4a0d-8704-44e2ee4a3caa  ...         43
#
# [2 rows x 3 columns]

# %%
f = '14a8b313-7c91-4a0d-8704-44e2ee4a3caa.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0   The United Nations projects that the number of...
# 1   Therapeutic approaches to age-associated neuro...  These changing demographics will also impact t...
# 2                                 Alzheimer's disease  AD is the most common form of dementia account...
# 3   Therapeutic approaches to neurocognitive disor...
# 4   Current pharmacological approaches to Alzheime...  Neurobiological features of AD, including accu...
# 5                       Neurotransmitter deficiencies  Cholinergic deficits. To date, the best-develo...
# 6                                ͱ-Amyloid deposition  Many believe that more directly targeting the ...
# 7                                        Inflammation  AD lesions are also characterized by the prese...
# 8         P h a r m a c o l o g i c a l a s p e c t s  As early as 1993, it was noted that patients w...
# ...

# %%
rep = ["Changing demographics have underscored the necessity to develop similar approaches for the remediation of the cognitive impairment associated with more benign syndromes, such as mild cognitive impairment (MCI) and age-associated cognitive decline (AACD)",
       'Therapeutic approaches to age-associated neurocognitive disorders',
       "Alzheimer's disease",
       "",
       "Current pharmacological approaches to Alzheimer's disease",
       'Neurotransmitter deficiencies', 'Amyloid deposition',
       'Inflammation', 'Pharmacological Aspects',
       'Oxidation', 'Neuronal degeneration', 'Neuroendocrine impairment',
       'Cerebrovascular and cardiovascular impairments',
       "Methodological and conceptual issues regarding therapeutic approaches to Alzheimer's disease",
       "Nonpharmacological approaches to Alzheimer's disease",
       "Future directions in Alzheimer's disease",
       'Cognitive change in normal aging',
       'Defining normal vs MCI vs pathological aging',
       'After much debate,ARCD became the Diagnostic and Statistical Manual of Mental Disorders-4th edition (DSM-IV)',
       '',
       'Inflammation and oxidation', 'Memory training',
       'Stress reduction', 'Physical and cognitive activity',
       'Current issues', 'Future directions in normal aging']


df1.text.replace(r'\bP h a r m a c o l o g i c a l a s p e c t s\b',
                     'Pharmacological Aspects', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 46

# %%
df[df.result_len == 46]
# Out:
#                                         Id  ... result_len
# 1357  bd10c47c-ff14-4076-a2d0-b93b60e88e82  ...         46
#
# [1 rows x 3 columns]

# %%
f = 'bd10c47c-ff14-4076-a2d0-b93b60e88e82.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                    ACKNOWLEDGEMENTS  I have been very lucky to have the opportunity...
# 1                                     LIST OF FIGURES
# 2             LIST OF FIGURES (Continued) Figure Page  Figure 24: Results for assimilation using SAR ...
# 3                                                . 45  Figure 32: Results for assimilation using a hi...
# 4                                      LIST OF TABLES
# 5                                                . 40
# 6                             Chapter 1: Introduction  The Mouth of the Columbia River (MCR) is a cri...
# 7                                   Model Description  The coupled ocean-atmosphere-wave-sediment tra...
# 8                            Environmental Conditions  It is important to understand the environmenta...
# ...

# %%
rep = ['ACKNOWLEDGEMENTS', '',
       '', '',
       '', '', 'Introduction',
       'Model Description', 'Environmental Conditions',
       'Bathymetry Inversion',
       'Computation of Covariance Matrices in Observational Domain',
       'Wave Direction Filtering',
       'General Application of Wave Direction Filter',
       'Results', 'Verification with Model-Derived Data',
       '',
       'Bathymetry estimates using SAR observations',
       '',
       '', '',
       'Sensitivity to Assigned Frequency for Each Observation',
       'Sensitivity to Assigned Frequency within Wave Direction Filter',
       'Evaluation of Additional SAR Observations and Future Work',
       'Additional Observation filtering', 'Limitations',
       'Conclusion']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 47

# %%
df[df.result_len == 47]
# Out:
#                                         Id  ... result_len
# 2812  89bcec78-76d4-430d-8d48-e6dde93c9534  ...         47
# 4400  393a9a10-1a02-4de1-81f6-9d6b027bd0d1  ...         47
#
# [2 rows x 3 columns]

# %%
f = '89bcec78-76d4-430d-8d48-e6dde93c9534.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                      section_title                                               text
# 0                                Executive Summary  TIMSS 2003 is the third in a continuing cycle ...
# 1        Students' Mathematics Achievement in 2003  • At both the eighth and fourth grades, Singap...
# 2                                EXECUTIVE SUMMARY  \nIn contrast, boys had higher achievement in ...
# 3                Trends in Mathematics Achievement  • At the eighth grade, several countries showe...
# 4    Gender Differences in Mathematics Achievement  • At the eighth grade, the gender difference i...
# ..                                             ...                                                ...
# 253                                         M13_12  Identifies the appropriate unit measure for an...
# 254                                       Geometry
# 255                                         M01_05           Identifies pairs of congruent triangles.
# ...

# %% [markdown]
# если честно это какая-то белеберда, просто рандомный текст в заголовках. Про текст я вообще молчу.
#
# Как из этого получить адекватную информацию совершенно не понятно.

# %%
rep =['Executive Summary', "",
       'EXECUTIVE SUMMARY', 'Trends in Mathematics Achievement',
       'Gender Differences in Mathematics Achievement',
       'Performance at the International Benchmarks in TIMSS 2003',
       "Students' Home Context for Learning Mathematics",
       'The Mathematics Curriculum', 'Teachers of Mathematics',
       'Classroom Instruction',
       'School Contexts for Learning and Instruction',
       'Who Conducts TIMSS?', 'INTRODUCTION',
       '',
       'What Is the Comparability Across the Grades and Ages Tested?',
       '', '', '', '', '',
       '', '', '', '',
       '', '', 'TIMSS2003', '', '',
       'What Was the Nature of the Mathematics Test and Background Questionnaires?',
       'How Do Country Characteristics Differ?', '',
       'How Do Countries Differ in Mathematics Achievement?',
       'INTERNATIONAL STUDENT ACHIEVEMENT IN MATHEMATICS',
       'Distribution of Mathematics Achievement', '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       "",
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       '',
       'Multiple Comparisons of Average Mathematics Achievement',
       'How Has Mathematics Achievement Changed Since 1995 and 1999?',
       '', 'PERFORMANCE AT INTERNATIONAL BENCHMARKS',
       'How Were the Benchmark Descriptions Developed?',
       'How Should the Descriptions Be Interpreted?',
       'Item Examples and Student Performance', 'MATHEMATICS',
       'Low International Benchmark -400',
       'Grade 8: Achievement at the Advanced International Benchmark',
       'Advanced International Benchmark -625', 'Summary', 'Grade',
       'Content Area: Data Country Percent Full Credit',
       'Country average significantly lower than international average',
       'High International Benchmark -550',
       'Content Area: Number Country Percent Full Credit', '2',
       'Content Area: Geometry Country Percent Full Credit',
       'Intermediate International Benchmark -475',
       'Content Area: Measurement Country Percent Full Credit',
       'Content Area: Patterns and Relationships Country Percent Full Credit',
       '',
       'AVERAGE ACHIEVEMENT IN THE MATHEMATICS CONTENT AREAS',
       'In Which Content Areas Are Countries Relatively Strong or Weak?',
       'Profiles of Within-Country Relative Performance in Mathematics Content Areas',
       'What Changes Have Occurred in Content Area Achievement?',
       '',
       'What Educational Resources Do Students Have in Their Homes?',
       "STUDENTS' BACKGROUNDS AND ATTITUDES TOWARDS MATHEMATICS",
       'Use of Computer',
       'How Much of Their Out-of-School Time Do Students Spend on Homework During the School Week?',
       'How Confident Are Students in Their Ability to Learn Mathematics?',
       '', ': THE MATHEMATICS CURRICULUM',
       'Which Countries Have a National Curriculum and Public Examinations in Mathematics?',
       'How Do Countries Support and Monitor Curriculum Implementation?',
       'How Much Instructional Time is Intended for Mathematics?',
       'Are the TIMSS Mathematics Topics Taught in School?',
       'Which TIMSS Mathematics Topics Are in the Intended and Implemented Curriculum?',
       '', '8', 'Geometry Countries',
       'Patterns and Relationships Countries', '',
       'What Are the Requirements for Being a Mathematics Teacher?',
       'TEACHERS OF MATHEMATICS',
       'What Preparation Do Teachers Have for Teaching Mathematics?',
       'Types of Interactions Among Mathematics Teachers',
       'How Ready Do Teachers Think They Are to Teach Mathematics?',
       '', 'Readiness to Teach Mathematics', '',
       'How Do the Characteristics of Mathematics Classrooms Impact Instruction?',
       'Class Size for Mathematics Instruction',
       'How Much School Time Is Devoted to Mathematics Instruction?',
       'CLASSROOM CHARACTERISTICS',
       'What Activities Do Students Do in Their Mathematics Lessons?',
       "Students' Reports on Mathematics Content Related Emphasis in Classroom Activities",
       'Textbook Use in Teaching Mathematics',
       'Percentage of Time in Mathematics Lessons Students Spend on Various Activities in a Typical Week',
       'Emphasis on Calculators in Mathematics Class',
       "Index of Teachers' Emphasis on Mathematics Homework (EMH)",
       'Use of Mathematics Homework', '',
       'SCHOOL CONTEXTS FOR LEARNING AND INSTRUCTION',
       'What Is the Level of School-Home Involvement?',
       'TIMSS & PIRLS INTERNATIONAL STUDY CENTER, LYNCH SCHOOL OF EDUCATION, BOSTON COLLEGE',
       'How Serious Are School Attendance Problems?',
       "Index of Mathematics Teachers' Perception of Safety in the Schools (TPSS)",
       "Index of Students' Perception of Being Safe in the Schools (SPBSS)",
       'Participants in TIMSS', 'Background Questionnaires',
       'Translation and Verification',
       'Population Definition and Sampling', 'Data Collection',
       'Scoring the Constructed-Response Items', 'Data Processing',
       'IRT Scaling and Data Analysis',
       'Assessing Statistical Significance',
       'Setting International Benchmarks of Student Achievement',
       'Calculator Use in the TIMSS 2003 Mathematics Assessment',
       '',
       'Multiple Comparisons of Average Achievement in Patterns and Relationships',
       'Multiple Comparisons of Average Achievement in Geometry',
       '',
       '',
       'Multiple Comparisons of Average Achievement in Data', '',
       '', '', '', '', '', '',
       '', '', '', '', '', '',
       '', '', '', '', '', '',
       '', '', '', '', '', '',
       '', '', '', '', '', '',
       '', '', '', '', '',
       '', '', '', '', '',
       'Measurement', '', '', '', '', '',
       '', '', '', '', '', '',
       '', '', '', '', '', '',
       '']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '393a9a10-1a02-4de1-81f6-9d6b027bd0d1.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                      section_title                                               text
# 0  C O R R E S P O N D E N C E O p e n A c c e s s  Absorbed plant MIR2911 in honeysuckle decoctio...

# %%
rep = ['CORRESPONDENCE Open Access']

df1.text.replace(r'\bC O R R E S P O N D E N C E O p e n A c c e s s\b',
                     'CORRESPONDENCE Open Access', regex=True, inplace = True)

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 49

# %%
df[df.result_len == 49]
# Out:
#                                         Id  ... result_len
# 3038  76dd5dd0-5012-4ebe-99ff-53986280ce19  ...         49
#
# [1 rows x 3 columns]

# %%
f = '76dd5dd0-5012-4ebe-99ff-53986280ce19.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                        section_title                                               text
# 0                                           Abstract  1. Biological monitoring programmes are increa...
# 1                                       Introduction  Biological monitoring programmes are fundament...
# 2                                            Methods
# 3               F A L S E -P O S I T I V E M O D E L  Existing Bayesian hierarchical occupancy model...
# 4                                 Simulation results  The false-positive model performed without bia...
# 5  E X A M P L E 2 : A N U R A N M O N I T O R I ...  To examine occurrence patterns of anurans in t...
# 6                          Anuran case study results  We obtained inference for occupancy probabilit...
# 7                                         Discussion  To understand the potential impacts of habitat...
# ...

# %%
rep =['Abstract', 'Introduction', '',
       'FALSE POSITIVE MODEL', 'Simulation results',
       'ANURAN MONITORING PROGRAMME',
       'Anuran case study results', 'Discussion',
       'FUTURE POTENTIAL EXTENSIONS', 'Conclusions']


rep_dict = {
    r'\bF A L S E -P O S I T I V E M O D E L\b':'FALSE POSITIVE MODEL',
    r'\bA N U R A N M O N I T O R I N G P R O G R A M M E\b':'ANURAN MONITORING PROGRAMME',
    r'\bF U T U R E P O T E N T I A L E X T E N S I O N S\b':'FUTURE POTENTIAL EXTENSIONS'
}
for (k, v) in rep_dict.items():
    df1.text.replace(k, v, regex=True, inplace = True)

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 50

# %%
df[df.result_len == 50]
# Out:
#                                         Id  ... result_len
# 3916  4fbebd85-7758-47c5-8964-00b7c98f06d5  ...         50
#
# [1 rows x 3 columns]

# %%
f = '4fbebd85-7758-47c5-8964-00b7c98f06d5.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  As neuroimaging databases grow in size and com...
# 1                                        Introduction  The neuroimaging community is producing imagin...
# 2                                              PyXNAT  We developed a Python library (PyX-NAT) to uni...
# 3                                Material and methods  We first review the different technologies and...
# 4                                              Python  We chose to use the Python language since it e...
# 5                                                XNAT
# 6                           Overview and key features  XNAT (Marcus et al., 2007) is an open source s...
# 7                                  XNAT search engine  XNAT features a powerful search engine with it...
# ...

# %%
rep = ['Abstract', 'Introduction', 'PyXNAT', 'Material and methods',
       'Python', '', 'Overview and key features',
       'XNAT search engine', 'The REST model', 'Resource type', 'Results',
       'Architecture and design', 'Object Mapper',
       "",
       '',
       'Search integration',
       "",
       "the online documentation session",
       'Database introspection',
       '',
       '',
       '',
       'Cache', 'Database management', 'Usage examples',
       'Discussion and Conclusion']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 53

# %%
df[df.result_len == 53]
# Out:
#                                         Id  ... result_len
# 3544  67ce912e-d8de-4f84-a86b-d0d77b9df591  ...         53
#
# [1 rows x 3 columns]

# %%
f = '67ce912e-d8de-4f84-a86b-d0d77b9df591.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                        Introduction  Today, one in four young children in the US is...
# 1                    Literature Review and Background  Immigrants and their children are key to Ameri...
# 2                                    Data and Methods  Our primary data source is the nationally repr...
# 3                 Parent demographic characteristics.  We focused on the spring parent survey to dete...
# 4   What Are the Demographics of Children of Immig...  Nationwide, nearly one-quarter of all kinderga...
# 5   Despite their economic need, low-income immigr...  Immigrant households with young children are l...
# 6   Immigrant families draw on considerable streng...  Children of immigrants are more likely to have...
# 7   Immigrant families speak a wide variety of lan...  Seventy-nine percent of children of immigrants...
# ...

# %%
rep = ['Introduction', 'Literature Review and Background',
       'Data and Methods', 'Parent demographic characteristics.',
       'What Are the Demographics of Children of Immigrants Entering Kindergarten in Fall 2010?',
       'Despite their economic need, low-income immigrant families draw on fewer public resources than their US-born peers.',
       'Immigrant families draw on considerable strengths.',
       'Immigrant families speak a wide variety of languages at home.',
       '',
       'What Are the Patterns of Early Care and Education Participation for Children of Immigrants in the Year before Kindergarten Entry?',
       '',
       'Children of immigrants and children of US-born parents, by income, entering kindergarten in 2010',
       'PREPARING THE FUTURE WORK FORCE',
       'In addition to child and family background characteristics, early care and education program features affect participation.',
       'Participation in center-based preschool matters for children of immigrants-particularly low-income children of immigrants.',
       'Recent developments in American immigration policy and enforcement may counter gains in access',
       'Conclusion', '']

df1.text.replace(r'\bP R E P A R I N G T H E F U T U R E W O R K F O R C E\b',
                     'PREPARING THE FUTURE WORK FORCE', regex=True, inplace = True)

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 55

# %%
df[df.result_len == 55]
# Out:
#                                         Id  ... result_len
# 1919  b01c7b5a-9863-4041-80e5-444424ea56fd  ...         55
# 2584  8432e134-5cb0-4dfc-8794-b5b05ac8dea3  ...         55
#
# [2 rows x 3 columns]

# %%
f = 'b01c7b5a-9863-4041-80e5-444424ea56fd.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0   ISSUE BRIEF ISSUE BRIEF T I M E L Y I N F O R ...  Mathematica ® strives to improve public well-b...
# 1   T R E N D S I N E D U C A T I O N R E S E A R ...  This brief summarizes the findings of Mathemat...
# 2                    Debate Over Academic Test Scores  The growing use of math and reading test score...
# 3                         Methods, Data, and Measures  Research has already examined the benefit for ...
# 4   Expanding Beyond Academics: Who Benefits and How?  ing type of competency and then formed measure...
# 5                      Math Versus Other Competencies  A key question is which competencies are most ...
# 6           Attitudes toward determinants of success.  Students who believe that success results from...
# 7   C O M P E T E N C I E S A N D T H E I R M E A ...  fraction would have benefited most from improv...
# ...

# %%
rep = ['ISSUE BRIEF ISSUE BRIEF TIMELY INFORMATION FROM MATHEMATICA',
       'TRENDSIN EDUCATION RESEARCH by John Deke and Joshua Haimson',
       'Debate Over Academic Test Scores', 'Methods, Data, and Measures',
       'Expanding Beyond Academics: Who Benefits and How?',
       'Math Versus Other Competencies',
       'Attitudes toward determinants of success.',
       'COMPETENCIES AND THEIR MEASURES',
       '',
       '', 'Different Students Have Different Needs',
       'Moving Forward']


rep_dict = {
    r'\bT I M E L Y I N F O R M A T I O N F R O M M A T H E M A T I C A\b':'TIMELY INFORMATION FROM MATHEMATICA',
    r'\bT R E N D S I N E D U C A T I O N R E S E A R C H\b':'TRENDSIN EDUCATION RESEARCH',
    r'\bC O M P E T E N C I E S A N D T H E I R M E A S U R E S\b':'COMPETENCIES AND THEIR MEASURES',
    r'\bP E R C E N TA G E O F S T U D E N T S F O R W H O M E A C H C O M P E T E N C Y H A S T H E G R E AT E S T E F F E C T\b': 'PERCENT AGE OF STUDENTS COMPETENCY HAS THE GREATEST EFFECT'

}
for (k, v) in rep_dict.items():
    df1.text.replace(k, v, regex=True, inplace = True)

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '8432e134-5cb0-4dfc-8794-b5b05ac8dea3.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  The National Weather Service (NWS) h a s d e v...
# 1                                                      p u t e h u r r i c a n e s t o r m s u r g e ...
# 2   SLOSH model h a s b e e n a p p l i e d t o mo...  Gulf of M e x i c o a n d A t l a n t i c c o ...
# 3                             I n a d d i t i o n t o  SLOSH'S u s e f o r r e a l -t i m e s u r g e...
# 4   h e m o d e l g e n e r a t e s t h e f l o o ...  Combining t h e s e f l o o d i n g p a t t e ...
# 5   i n d e t e rmining when e v a c u a t i o n r...  a comprehensive evacuation plan. One outcome o...
# 6                                        INTRODUCTION  S t o r m s u r g e --t h e s i g n i f i c a ...
# 7                                                  2.  T\nThe SLOSH model is two-dimensional i n s p ...
# ...

# %%
rep = ['Abstract', '',
       "SLOSH model has been applied to most of the United States'",
       '',
       '',
       '',
       'INTRODUCTION', '',
       'Input to the SLOSH model is limited to parameters that can in theory',
       '',
       "",
       '',
       "",
       '',
       'The amount of data produced by such runs is overwhelming',
       '',
       '', '']

df1.section_title = rep

t0 = 'The National Weather Service (NWS) has developed a hurricane storm surge model called SLOSH (Sea,Lake, and Overland Surges from hurricanes)'
t2 = 'Gulf of Mexico and Atlantic coast lines vulnerable to hurricanes. Description of the model suse and limitations for hurricane storm surge forecasting is presented Some specific examples of the use of SLOSH are drawn from Hurricane.'
t6 = 'Storm surge the significant increase in water level caused directly by a storm --poses the most serious threat to life along the coast from a hurricane.This storm ranks as the most devastating weather-related disaster for the United States . Galveston Island was completely overtopped by the surge generated by this great hurricane.Most of the deaths resulted from drowning ; virtually every building on the  island was destroyed . More recently , hurricane Camille i n 1969 devastated the Gulf Coast o astin the Gulf port , Miss. are a with a peak surgameasuring 24 feet ! This section of coastline wasthreateneda gain in 1985 by hurricane Elena. However, the region was spared from high surge because of a fortuitous trek . Two numerical models have been developed in the NWS attemptstof ore cast surge height for impending hurricane . First came the SPLASH model, which stand for Special Program to Get t h e Amplitude of Surges from Hurricanes . This model computes surges to and including coastline , unbroken by bays or estuaries. A more sophisticated mode l , SLOSH--for sea , Lake , a n d Overland Surges from hurricanes--extended the treatment of surges include flooding over inland water bodies , as well as overland flooding. In addition , the mode lt reats , in simple fashion , adverse followup rivers.For most are as of  the Gulf of Mexico and Atlantic Coasts , the SLOSH model has replaced SPLASH for estimates of hurricanes storm surge .'
t8 = 'at least before gatsby experience dhur hurricane forecaster . The first and most obvious putto SLOSH is hurricane strack. Six hourly , latitude and longitude track positions must be given 4 8 hour before landfall and 24 hours after landfall. In The Event of hurricane ot making land'
t14 = 'A teach SLOSH grid square , the highest value of surge from the ly of storm isdisplayed , giving composite call the Maximum Envelope of Waters , o r MEOW. Since a forecaster cant be certain of a hurricane landfall , we suggest that he exam inappropriate MEOW to estimate potential urge . Thise l im inates the possibility a ta critical path will be missed in which extreme values of surge could generated ,such as critical paths for long , narrow waterways . Hurricanes travel in governor to the right of a water ways axis (observer at sea , facing land) will produce little surge. However, for a hurricane which is to the left of this are roughly at a distance of the radius of maximum wind , extreme values of surge can be generated . The SLOSH user must keep in mind hatalla small portion of the coast line will experience the high flooding associated with a MEOW.'
df1.text.values[0] = t0
df1.text.values[2] = t2
df1.text.values[6] = t6
df1.text.values[8] = t8
df1.text.values[14] = t14

df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 57

# %%
df[df.result_len == 57]
# Out:
#                                        Id  ... result_len
# 578  e63cf45b-4da7-49d1-8d55-698f4fbb9bd7  ...         57
#
# [1 rows x 3 columns]

# %%
f = 'e63cf45b-4da7-49d1-8d55-698f4fbb9bd7.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                          section_title                                               text
# 0                                                       • In addition, two indicators provide insights...
# 1                           Data Sources and Estimates  The data in these indicators were obtained fro...
# 2                                      Standard Errors  Using estimates calculated from data based on ...
# 3                     Data Analysis and Interpretation  When estimates are from a sample, caution is w...
# 4                    Rounding and Other Considerations  All calculations within the indicators in this...
# ..                                                 ...                                                ...
# 103  Trends in International Mathematics and Scienc...  The Trends in International Mathematics and Sc...
# 104   Progress in International Reading Literacy Study  The Progress in International Reading Literacy...
# ...

# %%
rep = ['', 'Data Sources and Estimates', 'Standard Errors',
       'Data Analysis and Interpretation',
       'Rounding and Other Considerations', 'Race and Ethnicity',
       'Limitations of the Data', 'Symbols', 'Participation in Education',
       'Change between years', 'SOURCE: The Condition of Education 2017.',
       'At a Glance', 'Highlights From The Condition of Education 2017',
       'Spotlights',
       'Risk Factors and Academic Outcomes in Kindergarten Through Third Grade',
       'Homeless Children and Youth in Public Schools',
       "First-Time Postsecondary Students' Persistence After 3 Years",
       'Disability Rates and Employment Status by Educational Attainment',
       'Population Characteristics',
       'ATTAINMENT Educational Attainment of Young Adults',
       'ECONOMIC OUTCOMES',
       'Annual Earnings of Young Adults',
       'Employment and Unemployment Rates by Educational Attainment',
       'DEMOGRAPHICS',
       "Characteristics of Children's Families",
       "Children's Access to and Use of the Internet",
       'PREPRIMARY', 'Preschool and Kindergarten Enrollment',
       'ELEMENTARY SECONDARY',
       'Elementary and Secondary Enrollment',
       'English Language Learners in Public Schools',
       'Children and Youth With Disabilities',
       'POST SECONDARY', 'Undergraduate Enrollment',
       'Postbaccalaureate Enrollment',
       'Elementary and Secondary Education',
       'SCHOOL CHARACTER ISTICS AND CLIMATE',
       'Characteristics of Traditional Public Schools and Public Charter Schools',
       'Concentration of Public School Students Eligible for Free or Reduced-Price Lunch',
       'Technology and Engineering Literacy',
       'STUDENT EFFORT , PERSISTENCE , AND PROGRESS',
       'Public High School Graduation Rates', 'Status Dropout Rates',
       'Youth Neither Enrolled in School nor Working',
       'Immediate College Enrollment Rate', 'College Enrollment Rates',
       'Postsecondary Education POST SECONDARY ENVIRONMENT AND CHARACTERISTICS',
       'Characteristics of Degree-Granting Postsecondary Institutions',
       'Characteristics of Postsecondary Students',
       'Characteristics of Postsecondary Faculty',
       'PROGRAMS , COURSES , AND COMPLETIONS',
       'Undergraduate Degree Fields', 'Graduate Degree Fields',
       'Undergraduate Retention and Graduation Rates',
       'Postsecondary Certificates and Degrees Conferred',
       'Price of Attending an Undergraduate Institution',
       'Loans for Undergraduate Students', 'Sources of Financial Aid',
       'Postsecondary Institution Revenues',
       'Postsecondary Institution Expenses', 'Risk factors',
       '',
       'Reference tables: Digest of Education',
       '',
       'Percentages of persons with disabilities',
       'Employment of 25-to 64-year-olds with and without disabilities',
       'Unemployment percentages for 25-to 64-year-olds with and without disabilities',
       'Not-in-labor-force percentages for 25-to 64-year-olds with and without disabilities',
       'Endnotes:', 'Married-couple household',
       'Public Charter School Enrollment', 'Private School Enrollment',
       '', 'Mathematics Performance',
       '',
       '',
       '',
       '',
       '', 'Guide to Sources',
       'Beginning Postsecondary Students Longitudinal Study',
       'Local Education Agency (School District) Universe Survey',
       'National Public Education Financial Survey',
       'High School and Beyond Longitudinal Study',
       'High School Longitudinal Study of 2009',
       'Winter (Graduation Rates and Graduation Rates 200 Percent)',
       'Spring (Finance)', 'IPEDS Collection Years 2012-13 and Later',
       'IPEDS Collection Years Prior to 2012-13',
       'National Assessment of Educational Progress',
       'Main NAEP Assessments', 'NAEP Long-Term Trend Assessments',
       'National Postsecondary Student Aid Study',
       'Private School Universe Survey',
       'Projections of Education Statistics',
       'Bureau of Labor Statistics', 'Consumer Price Indexes',
       'Census Bureau', 'American Community Survey',
       'Census of Population-Education in the United States',
       'Current Population Survey', 'Computer and Internet Use',
       'School Crime Supplement',
       'Trends in International Mathematics and Science Study',
       'Progress in International Reading Literacy Study',
       'TIMSS and PIRLS Sampling and Response Rates', 'PIRLS',
       'TIMSS and TIMSS Advanced']


rep_dict = {
    r'\bA T T A I N M E N T\b':'ATTAINMENT',
    r'\bE C O N O M I C O U T C O M E S\b':'ECONOMIC OUTCOMES',
    r'\bD E M O G R A P H I C S\b':'DEMOGRAPHICS',
    r'\bP R E P R I M A R Y\b': 'PREPRIMARY',
    
    r'\bE L E M E N T A R Y/ S E C O N D A R Y\b':'ELEMENTARY SECONDARY',
    r'\bP O S T S E C O N D A R Y\b':'POST SECONDARY',
    r'\bS T U D E N T E F F O R T , P E R S I S T E N C E , A N D P R O G R E S S\b':'STUDENT EFFORT, PERSISTENCE, AND PROGRESS',
    r'\bS C H O O L C H A R A C T E R I S T I C S A N D C L I M A T E\b': 'SCHOOL CHARACTER ISTICS AND CLIMATE',

        
    r'\bP R O G R A M S , C O U R S E S , A N D C O M P L E T I O N S\b':'PROGRAMS, COURSES, AND COMPLETIONS',
    r'\bP O S T S E C O N D A R Y\b':'bPOST SECONDARY',
    r'\bP O S T S E C O N D A R Y E N V I R O N M E N T S A N D C H A R A C T E R I S T I C S\b':'POST SECONDARY ENVIRONMENTS AND CHARACTERISTICS'}
for (k, v) in rep_dict.items():
    df1.text.replace(k, v, regex=True, inplace = True)

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## 59

# %%
df[df.result_len == 59]
# Out:
#                                         Id  ... result_len
# 1768  af77a825-1dc4-4731-a970-e63aee041bfa  ...         59
# 4056  5ad0c517-799b-42ed-855d-e09692714c28  ...         59
# 4448  4797783c-4384-4227-a985-a08614d9024c  ...         59
# 5557  28b24247-96af-4df8-b9f0-b0aee2b3a27a  ...         59
# 5604  04fd49ad-466e-4d07-8848-2158e4994515  ...         59
#
# [5 rows x 3 columns]

# %%
f = 'af77a825-1dc4-4731-a970-e63aee041bfa.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                        INTRODUCTION  Sea level rise threatens to increase flooding ...
# 1                              RESULTS AND DISCUSSION
# 2                          Area of high-tide flooding  This study focuses on the effects of high-tide...
# 3   S C I E N C E A D V A N C E S | R E S E A R C ...  includes restaurants, hotels, and retail store...
# 4                     Incidence of high-tide flooding  Annapolis has a nuisance flood threshold that ...
# 5     Hourly flood impacts on local economic activity  To discern the impacts of high-tide flooding o...
# 6   Cumulative flood impacts on local economic act...  Building on the results from the regression an...
# 7                                         CONCLUSIONS  This analysis empirically estimates local busi...
# 8                               MATERIALS AND METHODS
# ...

# %%
rep = ['INTRODUCTION', '',
       'Area of high-tide flooding',
       'SCIENCE ADVANCES RESEARCH ARTICLE',
       'Incidence of high-tide flooding',
       'Hourly flood impacts on local economic activity',
       'Cumulative flood impacts on local economic activity',
       'CONCLUSIONS', '', 'Flood incidence',
       'Parking transactions', 'Counterfactual estimation',
       'Revenue losses', 'SUPPLEMENTARY MATERIALS']


df1.text.replace(r'\bS C I E N C E A D V A N C E S | R E S E A R C H A R T I C L E\b',
                     'SCIENCE ADVANCES RESEARCH ARTICLE', regex=True, inplace = True)

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '5ad0c517-799b-42ed-855d-e09692714c28.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  We used a first-of-its-kind comprehensive scen...
# 1                                        INTRODUCTION  Accelerating rates of sea-level rise (SLR) thr...
# 2                                             RESULTS  Our modeling demonstrates that the magnitude o...
# 3                                          DISCUSSION  In contrast to the Atlantic coast and the Gulf...
# 4                               MATERIALS AND METHODS  We investigated the temporal and spatial dimen...
# 5         Wetland elevation and spatial interpolation  To assess the current elevation profile of tid...
# 6                                    Wetland modeling  We examined the effects of SLR on tidal marsh ...
# 7                              Model parameterization  To parameterize WARMER, we collected sediment ...
# ...

# %%
rep =['Abstract', 'INTRODUCTION', 'RESULTS', 'DISCUSSION',
       'MATERIALS AND METHODS',
       'Wetland elevation and spatial interpolation', 'Wetland modeling',
       'Model parameterization',
       'SCIENCE ADVANCES RESEARCH ARTICLE',
       'Modeling certainty', 'Wetland transgression',
       'SUPPLEMENTARY MATERIALS']

df1.text.replace(r'\bS C I E N C E A D V A N C E S | R E S E A R C H A R T I C L E\b',
                     'SCIENCE ADVANCES RESEARCH ARTICLE', regex=True, inplace = True)

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '4797783c-4384-4227-a985-a08614d9024c.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  To assess whether recent seismicity is induced...
# 1                                        INTRODUCTION  A fundamental question about continental intra...
# 2                                             RESULTS  The Fort Worth Basin Recent seismic activity B...
# 3                                    Tectonic setting  The FWB is a north-south elongated foreland ba...
# 4                          Fault displacement history  Because of decades of extensive hydrocarbon ex...
# 5   The northern Mississippi embayment Tectonic se...  The Mississippi embayment is a southwest-dippi...
# 6   Fault displacement history and analysis of hig...
# 7                                     Reelfoot thrust  The first of these features, the Reelfoot thru...
# ...

# %%
rep = ['Abstract', 'INTRODUCTION', 'RESULTS', 'Tectonic setting',
       'Fault displacement history',
       'The northern Mississippi embayment Tectonic setting and seismicity',
       '',
       'Reelfoot thrust', 'Axial fault', 'Reelfoot rift margin',
       'DISCUSSION',
       'SCIENCE ADVANCES RESEARCH ARTICLE',
       'MATERIALS AND METHODS', 'SUPPLEMENTARY MATERIALS']


df1.text.replace(r'\bS C I E N C E A D V A N C E S | R E S E A R C H A R T I C L E\b',
                     'SCIENCE ADVANCES RESEARCH ARTICLE', regex=True, inplace = True)

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '28b24247-96af-4df8-b9f0-b0aee2b3a27a.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Earth's energy imbalance (EEI) drives the ongo...
# 1                                        INTRODUCTION  Global warming is driven by Earth's energy imb...
# 2                                             RESULTS  The efficiency of a mapping method We first ad...
# 3    Quantification of the global mean sampling error  The first step in quantifying the global mean ...
# 4       Quantification of the regional sampling error  It is also worthwhile examining the sampling e...
# 5               Regional OHC change in recent decades  Regional OHC changes are of great interest to ...
# 6     Implications for the planetary energy imbalance  This updated OHC estimate offers the opportuni...
# 7   S C I E N C E A D V A N C E S | R E S E A R C ...  In addition to warming the oceans, the energy ...
# ...

# %%
rep = ['Abstract', 'INTRODUCTION', 'RESULTS',
       'Quantification of the global mean sampling error',
       'Quantification of the regional sampling error',
       'Regional OHC change in recent decades',
       'Implications for the planetary energy imbalance',
       'SCIENCE ADVANCES RESEARCH ARTICLE',
       'DISCUSSION', '', 'Data', 'Mapping',
       'Subsample test', 'Statistical analysis',
       'SUPPLEMENTARY MATERIALS']

df1.text.replace(r'\bS C I E N C E A D V A N C E S | R E S E A R C H A R T I C L E\b',
                     'SCIENCE ADVANCES RESEARCH ARTICLE', regex=True, inplace = True)

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '04fd49ad-466e-4d07-8848-2158e4994515.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                        section_title                                               text
# 0                                           Abstract  Strong decadal variations in the oceanic uptak...
# 1                                       INTRODUCTION  The strength of ocean carbon uptake together w...
# 2                                            RESULTS  We analyze three sets of simulations from the ...
# 3                                                 −2  ). This trend difference and the increasing do...
# 4  S C I E N C E A D V A N C E S | R E S E A R C ...  In the North Pacific and the Southeastern Paci...
# 5                                         DISCUSSION  Our decadal prediction system provides a power...
# 6                              MATERIALS AND METHODS
# 7  Assimilation and preassimilation for ocean bio...  The assimilation is through nudging observatio...
# ...

# %%
rep = ['Abstract', 'INTRODUCTION', 'RESULTS', '',
       'SCIENCE ADVANCES RESEARCH ARTICLE',
       'DISCUSSION', '',
       'Assimilation and preassimilation for ocean biogeochemistry',
       'Predictive skill quantification', 'SUPPLEMENTARY MATERIALS']


df1.text.replace(r'\bS C I E N C E A D V A N C E S | R E S E A R C H A R T I C L E\b',
                     'SCIENCE ADVANCES RESEARCH ARTICLE', regex=True, inplace = True)

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %% [markdown]
# ## >59

# %%
df[df.result_len > 59]
# Out:
#                                         Id  ... result_len
# 232   f6cac0a3-fa06-4655-9200-283b5f7f4787  ...        791
# 475   dc40d75d-29a4-42bd-ad8f-d8bcf74c4855  ...         97
# 1171  d3be4116-047f-4215-a37b-1e5a6ce32ca1  ...         93
# 1206  d959c2e4-6627-4b9a-9e42-8d0cd50b4e88  ...         63
# 2079  ba89d8f4-2c5e-4c84-ba7b-e8d251f6d8a7  ...         71
# 2213  9fdfdc34-e5fc-4aa3-bacd-6817965ffac5  ...        159
# 2245  9b6c92ba-0400-4570-ba3e-b4ab9eb7c1f1  ...         65
# 2716  8ddfb8fb-66ce-43e1-b4c8-1c5492ffb95e  ...         71
# 3062  7487be4e-e324-4a13-b1ae-3c31117157f4  ...         71
# 3201  74a1f1c9-b3be-4ff2-8248-5203a521017e  ...        799
# 3553  685aa0e2-f6c9-48a9-9528-898756a181bf  ...       4491
# 3691  6fa9c138-5268-4d1b-a136-7401ca60e1c0  ...         71
# 4085  5b39755a-0914-4f90-9c8b-632e343eff81  ...        103
# 4744  2cffc88f-4a59-4777-a14e-ceeacd1d4ada  ...         71
# 4863  34eb8455-4045-4899-bb8f-f738a86d8ed9  ...        209
# ...

# %%
f = 'dc40d75d-29a4-42bd-ad8f-d8bcf74c4855.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                          section_title                                               text
# 0                                                       In the absence of large public investments in ...
# 1                                         INTRODUCTION  Cities across the United States are saddled wi...
# 2                             A GUIDE TO THIS RESEARCH  This research begins by reviewing of the roots...
# 3     THE ROOTS OF THE CARE CONUNDRUM CARE & CARE WORK  For all humans, the need for care extends acro...
# 4                 Concentric circles of care relations  In Kathleen Lynch's theoretical model of the t...
# ..                                                 ...                                                ...
# 143  I M P R O V E A C A D E M I C W O R K C U L T ...  Central to solving the child care conundrum at...
# 144  I M P L E M E N T B R O A D E R C A R E P O L ...  The results from our research underscored the ...
# ...

# %%
rep = ['', 'INTRODUCTION', 'A GUIDE TO THIS RESEARCH',
       'THE ROOTS OF THE CARE CONUNDRUM CARE & CARE WORK',
       'Concentric circles of care relations',
       'Differences in time spent on child care between women and men',
       'The largest caregiving occupations in the United States are mostly composed of women',
       "Source: Author's analysis of Center for Economic and Policy Research, 2013-2017, Current Population Survey",
       'THE CHANGING ROLE OF WOMEN',
       "Women's labor force participation has drastically risen since the 1970s in the United States",
       'CARE WORK SUPPLY MAY NOT MEET CARE WORK DEMAND',
       'A CARE CONUNDRUM IN THE UNITED STATES',
       'THE CASE OF EARLY CHILD CARE',
       'A BRIEF HISTORY OF CHILD CARE IN AMERICA',
       'A brief history of in child care policy in the United States',
       'THE AMERICAN EARLY CHILD CARE LANDSCAPE TODAY',
       'Early child care arrangements in the United States in 2016',
       'Source: U.S. Department of Education, National Center for Education Statistics, Early Childhood Program Participation Survey of the National Household Education Surveys Program (ECPP-NHES:2016).',
       'A breakdown of organized child care arrangements in the United States in 2016',
       "Early child care arrangements by mother's employment status the United States in 2016",
       "Early child care arrangements by mother's level of education the United States in 2016",
       'Early child care arrangements by household income the United States in 2016',
       'Child care availability by state in 2016',
       'Variations in percent of residents living in child care deserts by state in 2018',
       'Across the board, states had low shares of accredited child care programs in 2016',
       'THE COST OF CHILD CARE',
       'The average monthly cost of organized care by care arrangement in 2018',
       'The average cost burden of organized child care in 2016',
       'THE IMPOSSIBLE TRADEOFFS PROMPTED BY CHILD CARE',
       'POLICY RESPONSE TO THE GROWING CHILD CARE CRISIS',
       'ACADEMIC INSTITUTIONS & CHILD CARE',
       'CHILD CARE POLICIES AT ACADEMIC INSTITUTIONS TODAY',
       'A review of child care policies at top research universities in the United States',
       'Percent of public institutions and community colleges with on-campus child care in 2015',
       'WOMEN & THE LEAKY ACADEMIC PIPELINE',
       'Annual salary gaps between men and women in academia in 2018',
       'BUILDING A CASE FOR CHILD CARE',
       'RESEARCH QUESTION: QUANTIFYING THE COSTS OF UNMET CHILD CARE NEEDS FOR ACADEMIC PARENTS',
       '',
       'Modules of the 2019 Child Care for Parents in Academia Survey',
       'SURVEY MODULE DESCRIPTION OF QUESTIONS ASKED',
       'Current Child Care Arrangements',
       'Child Care Choice and Accessibility',
       'Child Care Quality',
       'Tradeoffs Associated with Child Care',
       'Demographics', 'MODULE G: Final Thoughts',
       'IDENTIFYING A SAMPLE POPULATION',
       'SURVEY DISTRIBUTION STRATEGY',
       'PRELIMINARY DESCRIPTIVE ANALYSIS',
       'DETERMINISTIC MODELING',
       'COST SO FUNNY CHILD CARE NEED TO ACADEMIC PARENTS & THEIR FAMILIES',
       'ESTIMATING THE SIZE OF THE ACADEMIC PARENT POPULATION WITH CHILDREN UNDER FIVE',
       'GENERATING AND CALIBRATING WEIGHTS THROUGH TALKING TO SCALE SAMPLE TO TALSTO POPULATION TOTALS',
       'LOST EARNINGS FROM UNPAID CHILD CARE WORK BY ACADEMIC PARENTS & OTHERS',
       'COSTS OF SPENDING ADDITIONAL TIME ON COMMUTING TO CHILD CARE ARRANGEMENTS',
       'COSTS OF USING BACK UP OPTIONS WHEN TYPICAL CHILD CARE ARRANGEMENTS BREAK DOWN OR ARE IN SUFFICIENT',
       'COSTS OF USING ALTERNATIVE CHILDCARE ARRANGEMENTS WHILEONA WAIT LIST FOR ON CAMPUS CHILD CARE',
       'LOST EARNINGS FROM QUITTING OR TAKING AN EXTENDED LEAVE OF ABSENCE DUE TO CHILDCARE TRADE OFFS',
       'COST OF PAID CHILD CARE',
       'OUTPUTS NOT INCLUDED IN THE COSTS TO ACADEMIC PARENTS AND THEIR FAMILIES MODEL',
       'COSTS OF UNMET CHILD CARE NEEDS TO ACADEMIC INSTITUTIONS',
       'ESTIMATING THE SIZE OF THE PARENT POPULATION WITH CHILDREN UNDER FIVE ATAC ACADEMIC INSTITUTIONS',
       'COST OF MISSING FULL DAY SOF WORK',
       'COST OF ARRIVING TO WORK LATE',
       'COST OF LEAVING WORK EARLY',
       'COST OF QUITTING OR TAKING AN EXTENDED LEAVE OF ABSENCE',
       'LOST REVENUES FROM THE LOWERED PRODUCTIVITY OF ACADEMIC PARENTS',
       'REGRESSION ANALYSIS',
       'THE RELATIONS HIP BETWEEN QUALITY RATING SO FLOCATION and OVERALL SATISFACTION WITH CHILD CARE',
       'THE RELATIONS HIP BETWEEN ADDED COMMUTE TO AND FROM CHILD CARE ARRANGEMENTS & QUALITY RATINGS OF LOCATION',
       'THE RELATIONS HIP BETWEEN PROXIMITY OF CHILD CARE ARRANGEMENTS TO HOME, WORK, OR ANO THER LOCATION & QUALITY RATING SO LOCATION',
       'THE RELATIONS HIP BETWEEN MODE OF TRANSPORTATION TO CHILD CARE ARRANGEMENT & QUALITY RATING SO FLOCATION',
       'A COMBINED MODEL FOR PREDICTING LOCATIONAL QUALITY RATINGS',
       'ABOUT THE SAMPLE',
       'CHILDREN UNDER AGE FIVE & THEIR CHARACTER IS TICS',
       'ACADEMIC PARENTS & THE IR CHARACTER IS TICS',
       'Details about parents represented in the 2019 Child Care for Academic Parents Survey',
       'Academic parents with young children surveyed tend to be lower on the tenure ladder',
       'Top fields of study among academic parents surveyed',
       'States represented in the sample of academic parents surveyed',
       'Annual earnings distribution across academic parents surveyed',
       '',
       'Annual earnings gaps between academic men and women parents surveyed',
       'ACADEMIC INSTITUTIONS & THEIR CHARACTERISTICS',
       'Details about academic institutions in the Child Care for Academic Parents Survey',
       'PRIMARY CHILD CARE ARRANGEMENTS',
       "A breakdown of academic parents' primary child care arrangements",
       "Academic parents' primary child care arrangements by the age of their children",
       '', 'AVAILABILITY & ACCESSIBILITY OF CHILD CARE',
       'Resources academic parents surveyed used to learn about child care options',
       'Challenges academic parents encountered in their search for child care',
       "Academic parents' preference for their current child care arrangement",
       'Perceptions about availability and accessibility of on-campus child care centers',
       'PERCEPTIONS ABOUT THE QU ALITY OF CHILD CARE',
       "Academic parents' overall satisfaction with their current child care arrangements",
       "Academic parents' quality ratings for their current child care arrangements",
       'COSTS OF CHILD CARE',
       'The cost of child care for academic parents surveyed exceeds the cost of in-state tuition',
       '',
       'The cost of child care by child care arrangement for academic parents surveyed',
       'Child care cost burdens by academic role of surveyed parent',
       'TRADEOFFS ASSOCIATED WITH CHILD CARE',
       'Changes academic parents make to work arrangements to meet child care needs',
       'THE COSTS OF UNMET CARE NEEDS: RESULTS FROM THE DETERMINISTIC MODEL',
       'COSTS OF UNMET CHILD CARE NEEDS TO ACADEMIC INSTITUTIONS',
       'A breakdown of the costs of child care to academic institutions',
       'A breakdown of the costs of child care to academic institutions by gender and type',
       'A DEEPER DIVE INTO LOCATION: RESULTS FROM REGRESSION ANALYSIS',
       'DO HIGHER QUALITY RATINGS OF LOCATION DRIVE HIGHER OVERALL SATISFACTION WITH CHILD CARE ARRANGEMENTS?',
       'Do higher quality ratings of location drive higher overall satisfaction with child care?',
       'ASSOCIATION BETWEEN LOCATION RATINGS AND OVERALL SATISFACTION',
       'DO LONGER ADDED COMMUTE TIMES TO AND FROM CHILD CARE ARRANGEMENTS REDUCE LOCATION QUALITY RATINGS?',
       'Do longer added commutes to and from child care reduce location quality ratings?',
       'ASSOCIATION BETWEEN COMMUTE TIME AND LOCATION RATINGS',
       "DOES CHILD CARE ARRANGEMENTS' CLOSENESS TO CERTAIN LOCATIONS CHANGE LOCATION QUALITY RATINGS?",
       'DOES THE MODE OF TRANSIT TO CHILD CARE ARRANGEMENTS CHANGE LO CATION QUALITY RATINGS?',
       'Does the mode of transit to child care change location quality ratings?',
       'ASSOCIATION BETWEEN MODE OF TRANSPORTATION AND LOCATION RATINGS',
       "HOW DO ALL THE DIFFERENT FEATURES OF LOCATION TOGETHER CHANGE CHILD CARE ARRANGEMENTS' LOCATION QUALITY RATINGS?",
       "How do the different features of child care's location change location quality ratings?",
       'ASSOCIATION BETWEEN FEATURES OF LOCATION AND LOCATION RATINGS',
       'INTERPRETING THE RESULTS',
       'A comparison of educational attainment between our survey and the general population',
       'CHILD CARE ARRANGEMENTS',
       'CHILD CARE CHOICE',
       'CHILD CARE PREFERENCES',
       'GENERAL CHILD CARE ACCESSIBILITY',
       'ON CAMPUS CHILD CARE ACCESSIBILITY',
       'CHILD CARE QUALITY', 'CHILD CARE COST',
       'CHILD CARE TRADE OFFS',
       'COST SO FUNMI CHILD CARE NEEDS',
       'LIMITATIONS',
       'LIMITATIONS OF THE CHILD CARE FOR PARENTS IN ACADEMIA SURVEY',
       'LIMITATIONS OF THE DETERMINISTIC MODEL',
       'LIMITATIONS OF THE REGRESSION ANALYSIS',
       'FILLING IN THE GAPS IN CHILD CARE NEEDS: RECOMMENDATIONS',
       'SET GUIDING PRINCIPLES',
       'EXPAND SUBSIDIES, GRANTS STIPENDS',
       'EXPAND ENHANCE ON CAMPUS CHILD CARE INFRASTRUCTURE',
       'CREAT ESTOP GAP CHILD CARE SUPPORTS',
       'IMPROVE ACADEMIC WORK CULTURE',
       'IMPLEMENT BROADER CARE POLICIES',
       'WORK ON EXTERNAL ADVOCACY AND ACTION WITH MUNICIPAL IES',
       'CONCLUSIONS',
       'APPENDICES APPENDIX A 2019 CHILD CARE FOR PARENTS IN ACADEMIA SURVEY']


df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = 'd3be4116-047f-4215-a37b-1e5a6ce32ca1.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                        Introduction  Severe acute respiratory syndrome coronavirus ...
# 1                               Materials and Methods  2.1. Acquisition and Analysis of Sequences. Un...
# 2                           Comparative and Ab Initio  Modeling. BlastP and FASTA searches were perfo...
# 3      Proteomics Analysis and Functional Annotation.  Sequence-based functional annotation was carri...
# 4                              Molecular Phylogenetic  Analysis. The amino sequences used for phyloge...
# 5                              Results and Discussion  3.1. Tertiary Structures of 9b and ORF14. The ...
# 6   Proteomics Profiles of 9b and ORF14. The Inter...  Search Result of ORF9b protein has revealed th...
# 7             Molecular Phylogeny of the 9b and ORF14  Proteins. Evolutionary analysis of the 9b and ...
# ...

# %%
rep = ['Introduction', 'Materials and Methods',
       'Comparative and Ab Initio',
       'Proteomics Analysis and Functional Annotation.',
       'Molecular Phylogenetic', 'Results and Discussion',
       'Proteomics Profiles of 9b and ORF14. The InterProScan',
       'Molecular Phylogeny of the 9b and ORF14',
       '',
       '',
       '', 'Conclusion', 'Data Availability', 'Additional Points',
       'Conflicts of Interest', "Authors' Contributions"]


df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = 'd959c2e4-6627-4b9a-9e42-8d0cd50b4e88.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                        section_title                                               text
# 0                                           Abstract  Aim: Decrease in physical activity has led to ...
# 1                                       Introduction  It is estimated that cardiovascular disease wi...
# 2                  II. Participants And Study Design  75 years (51.03±9.7) of which non-type 2 diabe...
# 3                                        IV. Results  Variance in heart rate and maximum predicted h...
# 4  i n H R i n o v e r w e i g h t B M I o v e r ...  Left side figure shows the mean % change in he...
# 5                                      V. Discussion  In this study we found that the overall preval...
# 6                     DOI: 10.9790/0853-150908136146  www.iosrjournals.org 143 | Page\nAs HR and max...
# 7                                     VI. Conclusion  Increase in BMI result in alteration of the au...

# %%
rep = ['Abstract', 'Introduction', 'Participants And Study Design',
       'Results',
       'in over weight',
       'Discussion', '',
       'Conclusion']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = 'ba89d8f4-2c5e-4c84-ba7b-e8d251f6d8a7.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                 H I G H L I G H T S  • As, Se, Pb and Fe mirrored reduction in indu...
# 1   G R A P H I C A L A B S T R A C T a b s t r a ...  Globally, the incidences of environmental impr...
# 2                                        Introduction  While the dreadful global lockdown to reduce t...
# 3                                          Study area  Tamil Nadu (TN) state in the southern India ha...
# 4                      Sample collection and analysis  A total of 22 samples were collected before lo...
# 5                        Principal component analyses  Factor analyses are the uncorrelated (orthogon...
# 6                                             Results  We evaluated the differences in groundwater qu...
# 7                         Physico-chemical parameters  The pH of samples before the lockdown (7.1-8.9...
# ...

# %%
rep = ['HIGHLIGHTS',
       'GRAPHICAL ABSTRACT abstract article info',
       'Introduction', 'Study area', 'Sample collection and analysis',
       'Principal component analyses', 'Results',
       'Physico-chemical parameters', 'Metals', 'Biological parameters',
       'Factor analyses', 'Discussion', 'Conclusion',
       'Declaration of competing interest']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '9fdfdc34-e5fc-4aa3-bacd-6817965ffac5.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                        section_title                                               text
# 0                                                     positions five to six years after graduation (...
# 1  B Y D A N I E L A B Ö T T J E R * , S E A N P....  career decisions: (1) expose students to diffe...
# 2  THE C-MORE PROFESSIONAL DEVELOPMENT TR AINING ...
# 3                                   CAREER WORKSHOPS  The three local career workshops aimed to: (1)...
# 4                               University of Hawaii

# %%
rep = ['',
       'BY DANIELA BÖTTJER , SEA N P. JUNGBLUTH, RENE BOITEAU , BRIAN BURKHARDT, FABIO DELEO , AND BARBARAC. BRUNO',
       '',
       'CAREER WORKSHOPS', 
       'University of Hawaii']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '9b6c92ba-0400-4570-ba3e-b4ab9eb7c1f1.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                        section_title                                               text
# 0                                           Abstract  OBJECTIVE -Cystatin C-and creatinine-based met...
# 1                                                  M  onitoring trends in renal function via glomeru...
# 2                                RESEARCH DESIGN AND  METHODS -A search of our database located 85 s...
# 3  P a t h o p h y s i o l o g y / C o m p l i c ...  dorsed by the Australian Creatinine Consensus ...

# %%
rep = ['Abstract', '', 'RESEARCH DESIGN AND', 'Pathophysiology Complications BRIEF']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '8ddfb8fb-66ce-43e1-b4c8-1c5492ffb95e.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Please cite this article as: Q. Dong, W. Zhang...
# 1                                        Introduction  Alzheimer's disease (AD), a progressive form o...
# 2                 A C C E P T E D M A N U S C R I P T  neuroimaging research, showing stronger statis...
# 3                               Materials and Methods
# 4                                            Database  Since January 1, 1994, cognitively normal resi...
# 5                                 ACCEPTED MANUSCRIPT  A C C E P T E D M A N U S C R I P T educationa...
# 6                                 Processing Pipeline
# 7   Hippocampus Segmentation and Hippocampal Surfa...  The automated hippocampus segmentations from i...
# 8   Conformal Parameterization-based Hippocampal S...  Generally, morphometry analysis requires defin...
# ...

# %%
rep = ['Abstract', 'Introduction', 'ACCEPTED MANUSCRIPT',
       '', 'Database', 'ACCEPTED MANUSCRIPT',
       '',
       'Hippocampus Segmentation and Hippocampal Surface Reconstruction',
       'Conformal Parameterization-based Hippocampal Surface Registration',
       'Hippocampal Morphometric Feature Extraction',
       'Statistical Group Differences of Hippocampal Morphometry',
       '', '',
       'Hippocampal Volume estimates of Three Levels of APOE-e4 Genotype Groups',
       'Hippocampal Morphometric Differences of the Contrast APOE-e4 Carriers vs. NC in Cognitively Unimpaired Individuals',
       '',
       'Unimpaired Individuals',
       '',
       'Different APOE-e4 Dose and NC in Cognitively Unimpaired Individuals',
       '',
       'Cumulative Distribution Analysis of the Hippocampal Morphometric Comparisons',
       'DISCUSSION',
       'Hippocampal Morphometric Differences of APOE-e4 Carriers vs. NC',
       'Hippocampal Morphometric Differences of NC vs. HT vs. HM',
       'Our Findings for Preclinical AD Research',
       'Deformation Directionality Analysis',
       'Subject Ages of the Studied Cohort', 'Limitation and Future Work',
       'reported the longitudinal Auditory Verbal Learning', 'CONCLUSION',
       'ACCEPTED MANUSCRIPT']

df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '7487be4e-e324-4a13-b1ae-3c31117157f4.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Changes in functional connectivity of cortical...
# 1                                                                    A C C E P T E D M A N U S C R I P T
# 2                                        Introduction  Evidence from combined functional MRI and amyl...
# 3                                 ACCEPTED MANUSCRIPT  A C C E P T E D M A N U S C R I P T 5 the phas...
# 4                            Participants and methods
# 5                                        Participants
# 6                 A C C E P T E D M A N U S C R I P T  6 local Institutional Review Board, and has be...
# 7                                   Cognitive testing  A comprehensive neuropsychological battery was...
# 8                                     MRI acquisition  MRI acquisitions of the brain were conducted u...
# ...

# %%
rep = ['Abstract', '', 'Introduction', 'ACCEPTED MANUSCRIPT',
       '', '',
       'A C C E P T E D M A N U S C R I P T', 'Cognitive testing',
       'MRI acquisition', 'PET acquisition', 'EEG acquisition',
       'PET processing', 'EEG processing', 'Statistical analyses',
       'Results', 'Discussion', '',
       '']


df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)
df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '74a1f1c9-b3be-4ff2-8248-5203a521017e.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                        Introduction  In 1998 the first comprehensive life cycle inv...
# 1                                         Methodology  Much of the attention directed toward renewabl...
# 2                         Data Description and Trends  At the time of the Sheehan et al. study, the m...
# 3                         Energy Life-Cycle Inventory  This section describes the inventory and data ...
# 4                                Feedstock Production  The farm input data for soybean production was...
# 5   Estimating Energy for Transporting Soybeans to...  Based on the rectilinear transportation system...
# 6   C C C C C C C C C C S C C S S C C C S C S S C ...  Figure 3: A hypothetical farm area with corn-c...
# 7   Estimating Energy for Oil Crushing and Biodies...  The production of biodiesel from soybeans occu...
# ...

# %%
rep = ['Introduction', 'Methodology', 'Data Description and Trends',
       'Energy Life-Cycle Inventory', 'Feedstock Production',
       'Estimating Energy for Transporting Soybeans to Biodiesel Plant',
       '',
       'Estimating Energy for Oil Crushing and Biodiesel Conversion',
       'Oil Extraction from Soybeans',
       'Conversion of Soybean Oil into Biodiesel',
       'Soy Oil Transportation', 'Biodiesel Production Model',
       'Biodiesel Transport', 'Calculating Energy Coproduct Values',
       'Results', 'Conclusion']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '685aa0e2-f6c9-48a9-9528-898756a181bf.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                        Introduction  The tendency of epidemics to return in repeate...
# 1   Estimating the reproduction number from incide...  Let S be the fraction of susceptible individua...
# 2       R(t)-reconstructions for individual countries  Since we do not have actual measurements of th...
# 3                     Cluster analysis of R(t)-curves  Rather than presenting reconstructions of R(t)...
# 4   A closed model for model for the epidemic evol...  The SIR-model does not constitute a closed mod...
# 5                The damped harmonic oscillator model  In this section we demonstrate that if X is cl...
# 6       A nonlinear, three-parameter oscillator model  Although the linear oscillator model gives som...
# 7   Fitting model parameters to the observed incid...  To validate the effectiveness of the proposed ...
# ...

# %%
rep = ['Introduction',
       'Estimating the reproduction number from incidence rate data',
       'R(t)-reconstructions for individual countries',
       'Cluster analysis of R(t)-curves',
       'A closed model for model for the epidemic evolution',
       'The damped harmonic oscillator model',
       'A nonlinear, three-parameter oscillator model',
       'Fitting model parameters to the observed incidence data',
       'Results of the cluster analysis of R(t)-curves',
       '',
       'Exploring the parameter space of the oscillator model',
       'The effect of the initial reproduction number',
       'The effect of the relaxation rate',
       'The effect of the intervention rate',
       'The effect of the fatigue rate', 'Discussion and conclusions']


df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '6fa9c138-5268-4d1b-a136-7401ca60e1c0.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  A multivariate analytical strategy may pinpoin...
# 1                 A C C E P T E D M A N U S C R I P T  Additionally, tractography technique on diffus...
# 2                                 ACCEPTED MANUSCRIPT  \n\n\n\n\n\nA C C E P T E D M A N U S C R I P ...
# 3                               Materials and Methods
# 4                                        Study cohort  The current study obtained MR images from the ...
# 5   Image acquisition, pre-processing and tractogr...
# 6                Definition of WM structural networks
# 7             Multivariate distance matrix regression  To more comprehensively characterize the alter...
# 8                                   Post-hoc analysis  While the overall connectivity pattern of a si...
# ...

# %%
rep = ['Abstract', 'ACCEPTED MANUSCRIPT',
       'ACCEPTED MANUSCRIPT', '', 'Study cohort',
       '',
       '',
       'Multivariate distance matrix regression', 'Post-hoc analysis',
       'Group-wise comparison of the overall connectivity strength',
       'Classification based on structural connectivity', '',
       '',
       'Brain regions with altered connectivity',
       'Connectivity patterns for seed regions',
       'Classification performance', 'Discussion',
       'ACCEPTED MANUSCRIPT']

df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '5b39755a-0914-4f90-9c8b-632e343eff81.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                        section_title                                               text
# 0                                           Abstract  Reliable predictions for species range changes...
# 1                                       INTRODUCTION  Predicted changes in biodiversity due to globa...
# 2                               MATERIAL AND METHODS  Occupancy models need repeated visits to a sit...
# 3                                            RESULTS  Model selection favoured the model where initi...
# 4                                         DISCUSSION  Do species change their ranges in response to ...
# 5  G G G G G G G G G G G G G S S S S S S S S S S ...  K K K K K K K K K K K K K f f f f f f f f f f ...
# 6  t t t t t t t t t t t t t F F F F F F F F F F ...  proportion of sites occupied Figure 2 . The pr...

# %%
rep = ['Abstract', 'INTRODUCTION', 'MATERIAL AND METHODS', 'RESULTS',
       'DISCUSSION',
       '',
       '']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '2cffc88f-4a59-4777-a14e-ceeacd1d4ada.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Brain white matter fiber bundles in patients w...
# 1   A C C E P T E D M A N U S C R I P T Introduction：  Alzheimer 's disease (AD) and its prodromal st...
# 2                 A C C E P T E D M A N U S C R I P T  These 20 tracts include association tracts, pr...
# 3                     Materials and Methods： Subjects  Eighty-eight participants were recruited from ...
# 4              Magnetic Resonance Imaging Acquisition  All magnetic resonance imaging scans were perf...
# 5             Magnetic Resonance Image Pre-processing  The pre-processing of DTI, voxel-based analysi...
# 6   Voxel-based analysis (VBA) & Tract-based spati...  First, register individual FA images of native...
# 7                Automated fiber quantification (AFQ)  3D-T 1 weighted images were used for registrat...
# ...

# %%
rep = ['Abstract', 'ACCEPTED MANUSCRIPT Introduction：',
       'ACCEPTED MANUSCRIPT',
       'Materials and Methods： Subjects',
       'Magnetic Resonance Imaging Acquisition',
       'Magnetic Resonance Image Pre-processing',
       'Voxel-based analysis (VBA) & Tract-based spatial statistics (TBSS)',
       'Automated fiber quantification (AFQ)', 'Statistical Analysis',
       '',
       'Demographics and clinical information from our cohort and ADNI cohort',
       'Mean diffusion measures of FA and MD among groups',
       'AD patients vs. NC subjects', 'MCI patients vs. NC subjects',
       'AD patients vs. MCI patients',
       'Tract Profiles of FA and MD among the group from our cohort',
       'Number of points with significant differences in tract profiles',
       'ACCEPTED MANUSCRIPT Tract Profiles of FA and MD among the groups from ADNI cohort',
       'The comparison among the VBA, TBSS and AFQ',
       'The comparison of the AFQ findings between ADNI cohort and our cohort',
       'Discussion',
       '',
       'Figures and legends', 'ACCEPTED MANUSCRIPT']

df1.text.replace(r'\bA C C E P T E D M A N U S C R I P T\b',
                     'ACCEPTED MANUSCRIPT', regex=True, inplace = True)

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '34eb8455-4045-4899-bb8f-f738a86d8ed9.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                     LIST OF FIGURES  . ANNUAL AVERAGE AMOUNTS OF REQUESTED SHORELIN...
# 1                                   EXECUTIVE SUMMARY  The Commonwealth of Virginia has extensive are...
# 2                            In Virginia tidal waters  o Approximately 11.1% of shoreline has been ha...
# 3       VULNERABILITY OF SHALLOW TIDAL WATER HABITATS  Projected shifts in coastal habitats • Shallow...
# 4                                        INTRODUCTION  The Commonwealth of Virginia has extensive are...
# 5             COASTAL HABITAT DEFINITIONS & STRESSORS  The nearshore environment is generally defined...
# 6                          Coastal Habitats Evaluated  Within the shallow tidal waters of the Chesape...
# 7                                 Shallow water areas  Inclusive of littoral waters between mean low ...
# ...

# %%
rep = ['LIST OF FIGURES', 'EXECUTIVE SUMMARY', 'In Virginia tidal waters',
       'VULNERABILITY OF SHALLOW TIDAL WATER HABITATS', 'INTRODUCTION',
       'COASTAL HABITAT DEFINITIONS & STRESSORS',
       'Coastal Habitats Evaluated', 'Shallow water areas',
       'Tidal wetlands', 'Submerged aquatic vegetation (SAV)',
       'Estuarine Beaches', 'CHESAPEAKE BAY SEGMENTATION',
       'Trends for each coastal habitat are presented for all tidal Virginia waters and by individual segment.',
       'CLIMATE CHANGE AND SHORELINE HARDENING',
       'SHORELINE HARDENING TRENDS', 'CLIMATE CHANGE MODEL COMPONENTS',
       'INUNDATION MODEL', 'BATHYMETRY', 'TOPOGRAPHY',
       'SEAMLESS 3-D TOPOGRAPHIC/BATHYMETRIC ELEVATION SURFACE Geographic coordinate system',
       'GIS Processing', 'Data Limitations', 'SEA LEVEL RISE SCENARIOS',
       'SEA LEVEL RISE IN THE CHESAPEAKE BAY',
       'MODELED SEA LEVEL RISE SCENARIOS',
       'Case Study: Sea Level Rise and Tidal Wetlands',
       'Temperature Projections', 'Salinity Projections',
       'COASTAL HABITAT SHIFTS WITH CLIMATE CHANGE',
       'SHALLOW WATER (BETWEEN MLW AND ≤ 2 M DEPTH)', 'HABITAT MODEL',
       'SHIFTS IN SHALLOW WATER', 'Change in Shallow Water Habitat (%)',
       'Present', 'SUBMERGED AQUATIC VEGETATION', 'HABITAT MODELS',
       'Eelgrass Beds -Polyhaline Waters',
       'Mixed SAV species -Mesohaline -Tidal Fresh Waters',
       'Model Limitations',
       '',
       'SUBMERGED AQUATIC VEGETATION & SEA LEVEL RISE Mesohaline --Tidal Fresh Waters',
       '-76% Loss of current SAV beds from SLR',
       'TIDAL WETLANDS TIDAL WETLANDS',
       'Potential Tidal Wetland Habitat (vegetated & non-vegetated wetlands)',
       'SHIFTS IN TIDAL WETLANDS',
       'Tidal Marsh Vulnerability (vegetated wetlands)',
       'Tidal Marsh Shifts Due to Salinity Changes',
       'VEGETATED TIDAL WETLANDS & SEA LEVEL RISE',
       'Marsh vulnerability to sea level rise',
       'High Risk Marsh Low Risk Marsh',
       'ESTUARINE BEACHES ESTUARINE BEACH HABITAT',
       'ESTUARINE BEACH VULNERABILITY MODEL LIMITATIONS',
       'SHIFTS IN ESTUARINE BEACHES',
       'SHALLOW WATER AND TIDAL WETLAND HABITAT SHIFTS WITH CLIMATE CHANGE',
       'TIDAL MARSH VULNERABILITY', 'ESTUARINE BEACH VULNERABILITY',
       'VULNERABLE DEVELOPED LANDS', 'SUMMARY']


df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '2f4dfbf7-3488-4758-925e-7f5599b5132e.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  • Boosted regression tree model produced 3D ma...
# 1                                 H I G H L I G H T S  • Boosted regression tree model produced 3D ma...
# 2   G R A P H I C A L A B S T R A C T a b s t r a ...
# 3                                        Introduction  Nitrate contamination of groundwater is a prob...
# 4                               Materials and methods
# 5                             Sources of nitrate data  We compiled a large database of groundwater ni...
# 6                                 Predictor variables  A database of 145 predictor variables was comp...
# 7                                    Machine learning  Prior research used regularization to improve ...
# 8                                   2D and 3D mapping  The 1 km nitrate prediction grids for each of ...
# ...

# %%
rep = ['Abstract', 'HIGHLIGHTS',
       '',
       'Introduction', '', 'Sources of nitrate data',
       'Predictor variables', 'Machine learning', '2D and 3D mapping',
       '', 'Summary statistics for sampled wells',
       '', 'Model training and testing',
       'Predictor variable influence',
       'Groundwater nitrate and mean age mapping', 'Conclusions']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '1e06cab6-5900-47f4-8dbe-cdc9a2924ffe.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  ABSTRACT\nThe Australian Imaging, Biomarkers a...
# 1                                        Introduction  There is a growing consensus that in order to ...
# 2                                             Methods
# 3                                        Participants  We sought to reassess the baseline cohort of 1...
# 4                                     Ethics approval  The AIBL study, including the 18-month follow-...
# 5                    Attendance for AIBL reassessment  Assessments took place at three locations in M...
# 6                       Cognitive and mood assessment  The AIBL cognitive and mood assessment has bee...
# 7          Blood samples and lifestyle questionnaires  The 80 ml blood samples taken on arrival were ...
# ...

# %%
rep = ['Abstract', 'Introduction', '', 'Participants',
       'Ethics approval', 'Attendance for AIBL reassessment',
       'Cognitive and mood assessment',
       'Blood samples and lifestyle questionnaires',
       'Medical history and medication use', 'Brain imaging',
       'Clinical review and the diagnosis of AD or MCI',
       'Statistical analyses', '', 'Cohort reassessment',
       'Demographic characteristics',
       'Neuropsychological change HEALTHY CONTROL ATB ASELINE',
       'MILD COGNITIVE IMPAIRMENT AT BASELINE',
       '',
       '',
       'Discussion', 'Conflict of interest',
       "Description of authors' roles"]

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '28fdd732-44e3-4423-a466-99ff4e5741d2.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                        section_title                                               text
# 0                                                     perceived as an early predictor of social mobi...
# 1  comPa ring eeo Findings W iTh recenT n aTion a...  It has now been fifty years since the EEO repo...
# 2                                                  :  program; and (5) "other." Similar to the categ...
# 3               asPir aTions a nd coLLege enroLLmenT  Since the 1960s, studies have shown that aspir...
# 4                                 coLLege knoW Ledge  Coleman did not view aspirations as the sole d...
# 5                                W h aT is mis sing?  These descriptive statistics suggest that the ...
# 6                                                  5  The value of college preparatory coursework ha...
# 7  : p o s t s e c o n d a r y a s p i r a t i o ...  of black students on average, whereas the aver...
# ...

# %%
rep = ['',
       'comParing Findings WiTh recenT naTionaL LongiTudinaL sTudies',
       '', 'asPiraTions and coLLege enroLLmenT', 'coLLege knoWLedge',
       'WhaT is missing?', '',
       'post secondary aspiration and enrollment',
       'modeLing coLLege enroLLmenT', 'discus sion']


df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '0bcf3d58-ebe6-4e3e-afc2-1ef881938667.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                        section_title                                               text
# 0                                                     SUMMARY. Advances in precision agriculture tec...
# 1                              Materials and methods
# 2  CHALLENGES ENCOUNTERED IN FRESH APPLE PRODUCTION.  We chose an ordered probit model to analyze gr...
# 3  B E N E F I T S A N D C O N C E R N S A S S O ...  We used a separate ordered probit model to ana...
# 4  INVESTMENT CONSIDERATION IN P R E C I S I O N ...  • April 2019 29 (2) TECHNOLOGIES. We used a bi...
# 5                             Results and discussion  SUMMARY STATISTICS. The largest farms in terms...
# 6  FAMILIARITY WITH AND USE OF P R E C I S I O N ...  TECHNOLOGIES. The size of the operation was st...
# 7  B E N E F I T S A N D C O N C E R N S A S S O ...  AGRICULTURE TECHNOLOGIES. Effectiveness of gre...
# ...

# %%
rep = ['', '',
       'CHALLENGES ENCOUNTERED IN FRESH APPLE PRODUCTION.',
       'BENEFITS AND CONCERNS ASSOCIATED WITH PREC ISION AGRICULTURE TECHNOLOGIES.',
       'INVESTMENT CONSIDERATION IN PRECISION AGRICULTURE',
       'Results and discussion',
       'FAMILIARITY WITH AND USE OF PRECISION AGRICUL TURE',
       'BENEFITS AND CONCERNS ASSOCIATED WITH PRECI SION',
       'Summary and conclusions', '']


df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '0f023524-318a-4fe3-8e5e-ed5fea6252f6.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Practical classes in immunology are important ...
# 1                                        INTRODUCTION  Our interest in this study is to scientificall...
# 2                                             Jiménez  Our group has been using the analysis methodol...
# 3                                         METHODOLOGY
# 4                                  The research sites  Basic Immunology discipline, this study partic...
# 5   The inquiry-based activity and its application...  The inquiry-based activity A complete descript...
# 6   Applications during undergraduate and graduate...  The inquiry-based activity was applied to the ...
# 7                                                  1)  Category A: data set to the result of characte...
# ...

# %%
rep = ['Abstract', 'INTRODUCTION', '', '',
       'The research sites',
       'The inquiry-based activity and its application during undergraduate classes and graduate Immunology classes',
       'Applications during undergraduate and graduate Immunology classes.',
       '', '', '', 'Data collection',
       'Analysis of the writings in "Laboratory notebooks"',
       'Epistemic practice Signification', 'Develop hypothesis',
       '', '',
       '', '', '', '',
       '', '', '', '',
       'Use data to theoretical evaluation', 'Assess consistency of data',
       '',
       'Analysis of epistemic practices presence in the writings of "Laboratory notebooks" filled out by groups of undergraduate and graduate students',
       'Questioning Develop hypothesis Making predictions Building data Consider different sources Conclude Mention Describe Explain Exemplify Opine Conceptualize Generalize Use data to theoretical evaluation',
       '', '', 'DISCUSSION']


df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
f = '104205fe-a235-45fd-ad20-0520f96e7235.json'
df1 = pd.read_json(Path(PATH) /'train' /f)
df1
# Out:
#                                         section_title                                               text
# 0                                            Abstract  Purpose To investigate the impact of amyloid P...
# 1                                        Introduction  Reliable biomarkers are a prerequisite for the...
# 2                               Materials and methods
# 3                                        Participants  The study population consisted of 207 patients...
# 4                      Neuropsychological assessments  Most patients completed a large battery of neu...
# 5                                  Structural imaging  Structural CT or T1-weighted MR imaging was pe...
# 6                                      CSF biomarkers  CSF samples were collected via lumbar puncture...
# 7                                  PET investigations  In addition to visual reads, semiquantitative ...
# ...

# %%
rep = ['Abstract', 'Introduction', '',
       'Participants', 'Neuropsychological assessments',
       'Structural imaging', 'CSF biomarkers', 'PET investigations',
       'Statistical analysis', 'Results', 'Discussion',
       'Flutemetamol PET positive  Apositive',
       'Conclusion', 'Compliance with ethical standards']

df1.section_title = rep
df1.to_json(Path(PATH_SAVE)/ f)

# %%
df1.section_title.values
# Out:
# array(['Abstract', 'Introduction', 'Materials and methods',
#        'Participants', 'Neuropsychological assessments',
#        'Structural imaging', 'CSF biomarkers', 'PET investigations',
#        'Statistical analysis', 'Results', 'Discussion',
#        'F ] f l u t e m e t a m o l P E T-p o s i t i v e . A p o s i t i v e [',
#        'Conclusion', 'Compliance with ethical standards'], dtype=object)

# %%
df1.text.values[11]
# Out:
# "18 F]flutemetamol PET scan in this group led mainly to a diagnosis of prodromal AD/AD, while a negative scan, with a few exceptions, led to a diagnosis of non-AD/dementia NOS, or (in a subset of MCI patients) to retention of the original diagnosis. Overall, amyloid PET led to a significant change in diagnosis in 44% of patients and an increase in the use of AD drug treatment, from 34 to 109 of 207 patients (16% to 53%). On the basis of our study design, in which amyloid PET results were used to revise initial diagnoses and treatment plans, our findings provide an estimate of the incremental value of this type of investigation in the clinical setting. Thus, this study fulfils the requirements of a phase 4 study as defined by the five-phase biomarker validation framework recently introduced to the field [34, 35] . This type of study is vital to assess the utility of amyloid PET and to accelerate the development of evidence-based guidelines for its clinical use [36] .\nIn the present s
# ...

# %% [markdown]
# ## to check same idea

# %%
len(df[df.result_len >= 19])
# Out:
# 158

# %%
# how make
# out = {}
# out_count = {}
# for f in tqdm(Path(PATH).glob('train/*.*')):
#     out[f.name] = np.mean(pd.read_json(f).text.str.split().apply(lambda x: len(x)))

# for f in tqdm(Path(PATH).glob('train/*.*')):
#     out_count[f.name] = pd.read_json(f).section_title.count()

# a = pd.DataFrame(out.items(), columns=['id', 'count_word'])
# b = pd.DataFrame(out_count.items(), columns=['id', 'count_title'])
# a.to_csv(PATH + '/count_words.csv')
# b.to_csv(PATH + '/count_title.csv')

# %%
# !ls '/content/drive/MyDrive/Coleridge_Initiative/input'
# Out:
# bad_data.csv	 data_tarin.csv  handles_fix		train
# count_title.csv  data_test.csv	 sample_submission.csv	train.csv
# count_words.csv  data_train_v1	 test

# %%
count_words = pd.read_csv(Path(PATH) / 'count_words.csv')
count_words.drop(['Unnamed: 0'],axis =1, inplace=True)
count_title = pd.read_csv(Path(PATH) / 'count_title.csv')
count_title.drop(['Unnamed: 0'],axis =1, inplace=True)

# %%
plt.figure(figsize=(10, 5))
plt.scatter(range(len(count_words[count_words.count_word < 2000].count_word.astype(int).values)),
            count_words[count_words.count_word < 2000].count_word.astype(int))
plt.axhline(y= int(count_words.count_word.mean()), color='r', linestyle='-')
plt.axhline(y= 1250, color='g', linestyle=':')
plt.yscale('linear')
plt.xlabel('Count Id\'s')
plt.ylabel('Count words in text')
# Out:
# Text(0, 0.5, 'Count words in text')

# %%
# skip json with one title(blanc) and big text0 and drop smalest param
count_words_drop = count_words.set_index('id').loc[count_title[count_title.count_title > 1]['id'].values]
fix_data = count_words_drop[count_words_drop.count_word < 1250].sort_values(by = ['count_word'])
fix_data

# %%
id_fix = []
c = 0
for i in Path(PATH_SAVE).glob('*.*'):
    c+=1
    if i.name in fix_data.index:
        id_fix.append(i.name)
    else:
        print(i)
print(c), len(id_fix)
# Out:
# /content/drive/MyDrive/Coleridge_Initiative/input/handles_fix/979fcaf1-cf50-4507-808e-6dc69c04e16a.json
# /content/drive/MyDrive/Coleridge_Initiative/input/handles_fix/a50bb821-b61d-4d79-904a-53b4e93ef9b0.json
# /content/drive/MyDrive/Coleridge_Initiative/input/handles_fix/393a9a10-1a02-4de1-81f6-9d6b027bd0d1.json
# 148

# %%
fix_data.reset_index().loc[~fix_data.reset_index()['id'].isin(id_fix)].to_csv(Path(PATH)/'fixed_list_id.csv', index =False)

# %%
fix_data.reset_index().loc[~fix_data.reset_index()['id'].isin(id_fix)]
# Out:
#                                               id   count_word
# 0      b042925c-6dde-4173-919b-0815bcb36435.json    17.592593
# 1      f15d0643-ebfc-4253-a722-88f74ec22407.json    29.071429
# 2      d056d52b-cf4d-4ec6-a59e-68935162a011.json    32.000000
# 3      87cdb3a0-036e-4ad4-b214-cffdd33047de.json    35.222222
# 4      39f10538-8a94-4d40-80a3-7af7988dcde4.json    37.916667
# ...                                          ...          ...
# 13997  d46b3a0e-ec54-47ef-aa7e-29bb0643d61c.json  1239.333333
# 13998  a0db9d9b-907f-4e5a-ae61-a86c6e531605.json  1241.666667
# 13999  d8a71d3a-3456-48b8-8b8a-75d05d345f18.json  1245.500000
# 14000  a3530208-3234-4fe6-9b2d-6a1072619843.json  1247.200000
# 14001  60e763a3-912a-497b-aad8-b38a11057ca4.json  1247.750000
#
# [13857 rows x 2 columns]

# %% [markdown]
# we find problem blanc title and very long text
#
# if title blanc check label in text if yes title set label
#
# if no skep
#
# del i json if count title =1 and text very long
#
# and drop count word > 2000 check
